# %%
# Libraries for data handling and model training
import numpy as np
import pandas as pd

# TensorFlow and Keras for building the CNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Just for context: Logs include a few metadata lines starting with '#', followed by numeric rows.
# Each numeric row layout: frame, steering, throttle, width, height, then 25*25 depth values
paths = [
    "cleaned_60.csv",
    "cleaned_61.csv",
    "cleaned_62.csv",
    "circuit_1.csv",
    "simple_strip.csv",
    "maze.csv",
    "dead_end.csv"
]

H, W = 25, 25
N_DEPTH = H * W

depth_cols = [f"d{i}" for i in range(N_DEPTH)]
col_names = ["frame", "steering", "throttle", "width", "height"] + depth_cols

dfs = []
for p in paths:
    tmp = pd.read_csv(
        p,
        comment="#", # ignore metadata + commented header lines
        header=None, # numeric data has no real header row
        names=col_names # assign stable column names
    )
    dfs.append(tmp)
df = pd.concat(dfs, ignore_index=True)

# %%
from sklearn.utils import shuffle
import cv2

# Targets: steering + throttle (kept as regression in normalized units)
Y_all = df[["steering", "throttle"]].to_numpy(dtype=np.float32)

# Inputs: depth grid as a single-channel 25x25 image + rotate
X_all = np.rot90(
    df[depth_cols]
      .to_numpy(dtype=np.float32)
      .reshape(-1, H, W, 1),
    k=-1,
    axes=(1, 2)
)
X_all = X_all / 2550

# Resize from 25×25 to target size
def resize_data(X, target_size=(24, 24)):
    """Resize images efficiently"""
    n_samples = X.shape[0]
    X_resized = np.zeros((n_samples, target_size[0], target_size[1], 1), dtype=np.float32)
    
    for i in range(n_samples):
        X_resized[i, :, :, 0] = cv2.resize(
            X[i, :, :, 0], 
            target_size, 
            interpolation=cv2.INTER_AREA  # Best for downsampling
        )
    
    return X_resized
  
# Apply resize
X_all = resize_data(X_all, target_size=(24, 24))
print(X_all.shape)
# Out:
# (25524, 24, 24, 1)

# %%
FRAMES_PER_BLOCK = 10

# %%
def create_blocks(X: np.ndarray, Y: np.ndarray, frame_count: int = 6):
    n = X.shape[0]
    usable = (n // frame_count) * frame_count
    
    X_trimmed = X[:usable]
    Y_trimmed = Y[:usable]
    
    # Select label from last frame of each block
    indices_for_y = np.arange(frame_count - 1, usable, frame_count)
    Y_grouped = Y_trimmed[indices_for_y]
    
    # Reshape into blocks
    X_grouped = X_trimmed.reshape(-1, frame_count, *X.shape[1:])
    # X_grouped shape: (batch, 6, 24, 24, 1)
    
    # Remove last singleton channel
    X_grouped = np.squeeze(X_grouped, axis=-1)
    # (batch, 6, 24, 24)
    
    # Move time dimension to channel axis
    X_grouped = np.transpose(X_grouped, (0, 2, 3, 1))
    # Final shape: (batch, 24, 24, 6)
    
    return X_grouped, Y_grouped


X, Y = create_blocks(X_all, Y_all, FRAMES_PER_BLOCK)
print(X.shape)
print(Y.shape)
# Out:
# (2552, 24, 24, 10)
# (2552, 2)

# %%
# ---- Create flipped copy ----
X_flip = np.flip(X, axis=2)      # horizontal flip (width axis)
Y_flip = Y.copy()
Y_flip[:, 0] = -Y_flip[:, 0]         # invert steering only

# ---- Append to original ----
X = np.concatenate([X, X_flip], axis=0)
Y = np.concatenate([Y, Y_flip], axis=0)


# ---- Shuffle the data ----
X, Y = shuffle(X, Y, random_state=42)

print("X:", X.shape)
print("X normalized min/max:", X.min(), X.max())
print("Y shape:", Y.shape)
print("Y min/max:", Y.min(axis=0), Y.max(axis=0))
# Out:
# X: (5104, 24, 24, 10)
# X normalized min/max: 0.023930982 1.0
# Y shape: (5104, 2)
# Y min/max: [-1. -1.] [1.    0.978]

# %%
from sklearn.model_selection import train_test_split

# First split: train (80%) and temp (20%)
X_train, X_temp, y_train, y_temp = train_test_split(
    X, Y,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Show 5 samples
for i in range(100, 105):
    fig, axes = plt.subplots(1, FRAMES_PER_BLOCK, figsize=(30, 3))
    
    for j in range(FRAMES_PER_BLOCK):
        axes[j].imshow(X[i, :, :, j], cmap='gray')
        axes[j].axis("off")
        axes[j].set_title(f"t-{5-j}" if j < 5 else "t")
    
    fig.suptitle(f"Sample {i}")
    plt.tight_layout()
    plt.show()

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.optimizers import Adam

inputs = Input(shape=(24, 24, 10))

# Proven stem
x = layers.Conv2D(16, 3, strides=2, padding="same", activation="relu")(inputs)  # 12x12
x = layers.SeparableConv2D(32, 3, strides=2, padding="same", activation="relu")(x)  # 6x6
x = layers.SeparableConv2D(32, 3, padding="same", activation="relu")(x)
x = layers.SeparableConv2D(48, 3, padding="same", activation="relu")(x)

# Proven attention
attention_map = layers.Conv2D(1, 1, activation="sigmoid")(x)
x = layers.Multiply()([x, attention_map])

x = layers.GlobalAveragePooling2D()(x)

# ONE targeted addition: bias initialization
# Rationale: This helped before and costs zero extra params
steering_mean = float(np.mean(y_train[:, 0]))
throttle_logit = float(np.log(
    np.mean(y_train[:, 1]) / (1 - np.mean(y_train[:, 1]))
))

x = layers.Dense(64, activation="relu")(x)
x = layers.Dropout(0.4)(x)

steering_out = layers.Dense(
    1, activation="tanh", name="steering",
    bias_initializer=tf.keras.initializers.Constant(steering_mean)
)(x)

throttle_out = layers.Dense(
    1, activation="sigmoid", name="throttle",
    bias_initializer=tf.keras.initializers.Constant(throttle_logit)
)(x)

model = Model(inputs=inputs, outputs=[steering_out, throttle_out])

model.compile(
    optimizer=Adam(1e-3),
    loss={"steering": "mse", "throttle": "mae"},
    metrics={"steering": ["mae"], "throttle": ["mae"]},
)

model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7       │ (None, 24, 24,    │          0 │ -                 │
# │ (InputLayer)        │ 10)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 12, 12,    │      1,456 │ input_layer_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_21 │ (None, 6, 6, 32)  │        688 │ conv2d_14[0][0]   │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_22 │ (None, 6, 6, 32)  │      1,344 │ separable_conv2d… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_23 │ (None, 6, 6, 48)  │      1,872 │ separable_conv2d… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 6, 6, 1)   │         49 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 6, 6, 48)  │          0 │ separable_conv2d… │
# │ (Multiply)          │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ multiply_7[0][0]  │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 64)        │      3,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64)        │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ steering (Dense)    │ (None, 1)         │         65 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ throttle (Dense)    │ (None, 1)         │         65 │ dropout_6[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,675 (33.89 KB)
#  Trainable params: 8,675 (33.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
import datetime

# Create callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        'best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    TensorBoard(
        log_dir=f'logs/{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}',
        histogram_freq=1
    )
]

# Train using combined control output
history = model.fit(
    X_train,
    {
        "steering": y_train[:, 0],   # First column: steering
        "throttle": y_train[:, 1]    # Second column: throttle
    },
    validation_data=(
        X_temp, 
        {
            "steering": y_temp[:, 0],
            "throttle": y_temp[:, 1]
        }
    ),
    epochs=150,
    batch_size=64,
    callbacks=callbacks
)
# Out:
# Epoch 1/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6481 - steering_loss: 0.0538 - steering_mae: 0.1452 - throttle_loss: 0.5942 - throttle_mae: 0.5942
# Epoch 1: val_loss improved from None to 0.20500, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.4619 - steering_loss: 0.0584 - steering_mae: 0.1607 - throttle_loss: 0.4026 - throttle_mae: 0.4034 - val_loss: 0.2050 - val_steering_loss: 0.0541 - val_steering_mae: 0.1425 - val_throttle_loss: 0.1508 - val_throttle_mae: 0.1508 - learning_rate: 0.0010
# Epoch 2/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2514 - steering_loss: 0.0580 - steering_mae: 0.1629 - throttle_loss: 0.1935 - throttle_mae: 0.1935
# Epoch 2: val_loss improved from 0.20500 to 0.20410, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2451 - steering_loss: 0.0571 - steering_mae: 0.1635 - throttle_loss: 0.1878 - throttle_mae: 0.1879 - val_loss: 0.2041 - val_steering_loss: 0.0539 - val_steering_mae: 0.1400 - val_throttle_loss: 0.1502 - val_throttle_mae: 0.1502 - learning_rate: 0.0010
# Epoch 3/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2404 - steering_loss: 0.0561 - steering_mae: 0.1590 - throttle_loss: 0.1844 - throttle_mae: 0.1844
# Epoch 3: val_loss did not improve from 0.20410
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2382 - steering_loss: 0.0564 - steering_mae: 0.1574 - throttle_loss: 0.1821 - throttle_mae: 0.1819 - val_loss: 0.2130 - val_steering_loss: 0.0537 - val_steering_mae: 0.1389 - val_throttle_loss: 0.1594 - val_throttle_mae: 0.1593 - learning_rate: 0.0010
# Epoch 4/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2291 - steering_loss: 0.0509 - steering_mae: 0.1478 - throttle_loss: 0.1782 - throttle_mae: 0.1782
# Epoch 4: val_loss did not improve from 0.20410
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2329 - steering_loss: 0.0537 - steering_mae: 0.1491 - throttle_loss: 0.1792 - throttle_mae: 0.1792 - val_loss: 0.2055 - val_steering_loss: 0.0537 - val_steering_mae: 0.1383 - val_throttle_loss: 0.1518 - val_throttle_mae: 0.1518 - learning_rate: 0.0010
# Epoch 5/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2293 - steering_loss: 0.0506 - steering_mae: 0.1421 - throttle_loss: 0.1787 - throttle_mae: 0.1787
# Epoch 5: val_loss improved from 0.20410 to 0.20380, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2331 - steering_loss: 0.0530 - steering_mae: 0.1458 - throttle_loss: 0.1802 - throttle_mae: 0.1801 - val_loss: 0.2038 - val_steering_loss: 0.0538 - val_steering_mae: 0.1390 - val_throttle_loss: 0.1500 - val_throttle_mae: 0.1500 - learning_rate: 0.0010
# Epoch 6/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2290 - steering_loss: 0.0527 - steering_mae: 0.1440 - throttle_loss: 0.1764 - throttle_mae: 0.1764
# Epoch 6: val_loss improved from 0.20380 to 0.20207, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2282 - steering_loss: 0.0521 - steering_mae: 0.1432 - throttle_loss: 0.1760 - throttle_mae: 0.1760 - val_loss: 0.2021 - val_steering_loss: 0.0537 - val_steering_mae: 0.1387 - val_throttle_loss: 0.1484 - val_throttle_mae: 0.1484 - learning_rate: 0.0010
# Epoch 7/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2164 - steering_loss: 0.0454 - steering_mae: 0.1352 - throttle_loss: 0.1710 - throttle_mae: 0.1710
# Epoch 7: val_loss did not improve from 0.20207
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2254 - steering_loss: 0.0514 - steering_mae: 0.1415 - throttle_loss: 0.1741 - throttle_mae: 0.1740 - val_loss: 0.2038 - val_steering_loss: 0.0536 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1501 - val_throttle_mae: 0.1501 - learning_rate: 0.0010
# Epoch 8/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2226 - steering_loss: 0.0518 - steering_mae: 0.1394 - throttle_loss: 0.1708 - throttle_mae: 0.1708
# Epoch 8: val_loss did not improve from 0.20207
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2237 - steering_loss: 0.0509 - steering_mae: 0.1386 - throttle_loss: 0.1727 - throttle_mae: 0.1727 - val_loss: 0.2030 - val_steering_loss: 0.0537 - val_steering_mae: 0.1387 - val_throttle_loss: 0.1494 - val_throttle_mae: 0.1494 - learning_rate: 0.0010
# Epoch 9/150
# 54/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2213 - steering_loss: 0.0484 - steering_mae: 0.1363 - throttle_loss: 0.1728 - throttle_mae: 0.1728
# Epoch 9: val_loss improved from 0.20207 to 0.20197, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2193 - steering_loss: 0.0505 - steering_mae: 0.1368 - throttle_loss: 0.1689 - throttle_mae: 0.1688 - val_loss: 0.2020 - val_steering_loss: 0.0536 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1484 - val_throttle_mae: 0.1483 - learning_rate: 0.0010
# Epoch 10/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2206 - steering_loss: 0.0495 - steering_mae: 0.1338 - throttle_loss: 0.1711 - throttle_mae: 0.1711
# Epoch 10: val_loss improved from 0.20197 to 0.20060, saving model to best_model.keras
#
# Epoch 10: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2182 - steering_loss: 0.0505 - steering_mae: 0.1367 - throttle_loss: 0.1676 - throttle_mae: 0.1677 - val_loss: 0.2006 - val_steering_loss: 0.0536 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1470 - val_throttle_mae: 0.1469 - learning_rate: 0.0010
# Epoch 11/150
# 62/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2168 - steering_loss: 0.0501 - steering_mae: 0.1359 - throttle_loss: 0.1666 - throttle_mae: 0.1666
# Epoch 11: val_loss improved from 0.20060 to 0.20028, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2178 - steering_loss: 0.0505 - steering_mae: 0.1357 - throttle_loss: 0.1672 - throttle_mae: 0.1673 - val_loss: 0.2003 - val_steering_loss: 0.0536 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1466 - val_throttle_mae: 0.1466 - learning_rate: 0.0010
# Epoch 12/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2157 - steering_loss: 0.0489 - steering_mae: 0.1330 - throttle_loss: 0.1668 - throttle_mae: 0.1668
# Epoch 12: val_loss did not improve from 0.20028
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2175 - steering_loss: 0.0501 - steering_mae: 0.1347 - throttle_loss: 0.1673 - throttle_mae: 0.1673 - val_loss: 0.2046 - val_steering_loss: 0.0536 - val_steering_mae: 0.1383 - val_throttle_loss: 0.1510 - val_throttle_mae: 0.1509 - learning_rate: 0.0010
# Epoch 13/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2167 - steering_loss: 0.0502 - steering_mae: 0.1348 - throttle_loss: 0.1665 - throttle_mae: 0.1665
# Epoch 13: val_loss improved from 0.20028 to 0.19918, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2144 - steering_loss: 0.0502 - steering_mae: 0.1343 - throttle_loss: 0.1641 - throttle_mae: 0.1643 - val_loss: 0.1992 - val_steering_loss: 0.0536 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1456 - val_throttle_mae: 0.1455 - learning_rate: 0.0010
# Epoch 14/150
# 62/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2098 - steering_loss: 0.0476 - steering_mae: 0.1313 - throttle_loss: 0.1622 - throttle_mae: 0.1622
# Epoch 14: val_loss did not improve from 0.19918
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2142 - steering_loss: 0.0502 - steering_mae: 0.1342 - throttle_loss: 0.1640 - throttle_mae: 0.1640 - val_loss: 0.1992 - val_steering_loss: 0.0536 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1456 - val_throttle_mae: 0.1456 - learning_rate: 0.0010
# Epoch 15/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2261 - steering_loss: 0.0566 - steering_mae: 0.1420 - throttle_loss: 0.1695 - throttle_mae: 0.1695
# Epoch 15: val_loss did not improve from 0.19918
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2169 - steering_loss: 0.0501 - steering_mae: 0.1340 - throttle_loss: 0.1668 - throttle_mae: 0.1668 - val_loss: 0.2066 - val_steering_loss: 0.0537 - val_steering_mae: 0.1387 - val_throttle_loss: 0.1528 - val_throttle_mae: 0.1528 - learning_rate: 0.0010
# Epoch 16/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2121 - steering_loss: 0.0493 - steering_mae: 0.1324 - throttle_loss: 0.1629 - throttle_mae: 0.1629
# Epoch 16: val_loss improved from 0.19918 to 0.19915, saving model to best_model.keras
#
# Epoch 16: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2127 - steering_loss: 0.0500 - steering_mae: 0.1334 - throttle_loss: 0.1626 - throttle_mae: 0.1627 - val_loss: 0.1992 - val_steering_loss: 0.0536 - val_steering_mae: 0.1383 - val_throttle_loss: 0.1455 - val_throttle_mae: 0.1455 - learning_rate: 0.0010
# Epoch 17/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2149 - steering_loss: 0.0499 - steering_mae: 0.1314 - throttle_loss: 0.1650 - throttle_mae: 0.1650
# Epoch 17: val_loss improved from 0.19915 to 0.19913, saving model to best_model.keras
#
# Epoch 17: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2103 - steering_loss: 0.0502 - steering_mae: 0.1330 - throttle_loss: 0.1601 - throttle_mae: 0.1602 - val_loss: 0.1991 - val_steering_loss: 0.0537 - val_steering_mae: 0.1389 - val_throttle_loss: 0.1454 - val_throttle_mae: 0.1454 - learning_rate: 0.0010
# Epoch 18/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2062 - steering_loss: 0.0504 - steering_mae: 0.1338 - throttle_loss: 0.1559 - throttle_mae: 0.1559
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 18: val_loss did not improve from 0.19913
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2080 - steering_loss: 0.0499 - steering_mae: 0.1330 - throttle_loss: 0.1578 - throttle_mae: 0.1579 - val_loss: 0.2041 - val_steering_loss: 0.0536 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1505 - val_throttle_mae: 0.1505 - learning_rate: 0.0010
# Epoch 19/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2100 - steering_loss: 0.0521 - steering_mae: 0.1347 - throttle_loss: 0.1579 - throttle_mae: 0.1579
# Epoch 19: val_loss improved from 0.19913 to 0.19872, saving model to best_model.keras
#
# Epoch 19: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2080 - steering_loss: 0.0503 - steering_mae: 0.1327 - throttle_loss: 0.1579 - throttle_mae: 0.1578 - val_loss: 0.1987 - val_steering_loss: 0.0536 - val_steering_mae: 0.1384 - val_throttle_loss: 0.1451 - val_throttle_mae: 0.1451 - learning_rate: 5.0000e-04
# Epoch 20/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2025 - steering_loss: 0.0467 - steering_mae: 0.1296 - throttle_loss: 0.1559 - throttle_mae: 0.1559
# Epoch 20: val_loss did not improve from 0.19872
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2095 - steering_loss: 0.0500 - steering_mae: 0.1323 - throttle_loss: 0.1594 - throttle_mae: 0.1595 - val_loss: 0.1988 - val_steering_loss: 0.0537 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1452 - val_throttle_mae: 0.1451 - learning_rate: 5.0000e-04
# Epoch 21/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2080 - steering_loss: 0.0483 - steering_mae: 0.1304 - throttle_loss: 0.1597 - throttle_mae: 0.1597
# Epoch 21: val_loss improved from 0.19872 to 0.19793, saving model to best_model.keras
#
# Epoch 21: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2088 - steering_loss: 0.0501 - steering_mae: 0.1323 - throttle_loss: 0.1590 - throttle_mae: 0.1588 - val_loss: 0.1979 - val_steering_loss: 0.0537 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1443 - val_throttle_mae: 0.1442 - learning_rate: 5.0000e-04
# Epoch 22/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2064 - steering_loss: 0.0505 - steering_mae: 0.1324 - throttle_loss: 0.1559 - throttle_mae: 0.1559
# Epoch 22: val_loss did not improve from 0.19793
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2066 - steering_loss: 0.0499 - steering_mae: 0.1322 - throttle_loss: 0.1566 - throttle_mae: 0.1566 - val_loss: 0.1980 - val_steering_loss: 0.0537 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1444 - val_throttle_mae: 0.1443 - learning_rate: 5.0000e-04
# Epoch 23/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2065 - steering_loss: 0.0483 - steering_mae: 0.1300 - throttle_loss: 0.1583 - throttle_mae: 0.1583
# Epoch 23: val_loss did not improve from 0.19793
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2081 - steering_loss: 0.0499 - steering_mae: 0.1321 - throttle_loss: 0.1581 - throttle_mae: 0.1582 - val_loss: 0.2034 - val_steering_loss: 0.0536 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1497 - val_throttle_mae: 0.1497 - learning_rate: 5.0000e-04
# Epoch 24/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2016 - steering_loss: 0.0462 - steering_mae: 0.1292 - throttle_loss: 0.1553 - throttle_mae: 0.1553
# Epoch 24: val_loss improved from 0.19793 to 0.19756, saving model to best_model.keras
#
# Epoch 24: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2057 - steering_loss: 0.0500 - steering_mae: 0.1321 - throttle_loss: 0.1559 - throttle_mae: 0.1557 - val_loss: 0.1976 - val_steering_loss: 0.0537 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1439 - val_throttle_mae: 0.1439 - learning_rate: 5.0000e-04
# Epoch 25/150
# 54/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2074 - steering_loss: 0.0504 - steering_mae: 0.1336 - throttle_loss: 0.1570 - throttle_mae: 0.1570
# Epoch 25: val_loss improved from 0.19756 to 0.19698, saving model to best_model.keras
#
# Epoch 25: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2049 - steering_loss: 0.0499 - steering_mae: 0.1324 - throttle_loss: 0.1549 - throttle_mae: 0.1550 - val_loss: 0.1970 - val_steering_loss: 0.0536 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1433 - val_throttle_mae: 0.1433 - learning_rate: 5.0000e-04
# Epoch 26/150
# 53/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2059 - steering_loss: 0.0490 - steering_mae: 0.1312 - throttle_loss: 0.1569 - throttle_mae: 0.1569
# Epoch 26: val_loss improved from 0.19698 to 0.19671, saving model to best_model.keras
#
# Epoch 26: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2053 - steering_loss: 0.0500 - steering_mae: 0.1323 - throttle_loss: 0.1553 - throttle_mae: 0.1554 - val_loss: 0.1967 - val_steering_loss: 0.0537 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1431 - val_throttle_mae: 0.1430 - learning_rate: 5.0000e-04
# Epoch 27/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1990 - steering_loss: 0.0469 - steering_mae: 0.1274 - throttle_loss: 0.1521 - throttle_mae: 0.1521
# Epoch 27: val_loss did not improve from 0.19671
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2049 - steering_loss: 0.0498 - steering_mae: 0.1321 - throttle_loss: 0.1551 - throttle_mae: 0.1551 - val_loss: 0.1977 - val_steering_loss: 0.0537 - val_steering_mae: 0.1386 - val_throttle_loss: 0.1440 - val_throttle_mae: 0.1440 - learning_rate: 5.0000e-04
# Epoch 28/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1995 - steering_loss: 0.0476 - steering_mae: 0.1296 - throttle_loss: 0.1519 - throttle_mae: 0.1519
# Epoch 28: val_loss improved from 0.19671 to 0.19578, saving model to best_model.keras
#
# Epoch 28: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2041 - steering_loss: 0.0499 - steering_mae: 0.1322 - throttle_loss: 0.1542 - throttle_mae: 0.1541 - val_loss: 0.1958 - val_steering_loss: 0.0537 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1421 - val_throttle_mae: 0.1421 - learning_rate: 5.0000e-04
# Epoch 29/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2028 - steering_loss: 0.0517 - steering_mae: 0.1351 - throttle_loss: 0.1512 - throttle_mae: 0.1512
# Epoch 29: val_loss did not improve from 0.19578
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2028 - steering_loss: 0.0500 - steering_mae: 0.1324 - throttle_loss: 0.1528 - throttle_mae: 0.1528 - val_loss: 0.1964 - val_steering_loss: 0.0536 - val_steering_mae: 0.1384 - val_throttle_loss: 0.1428 - val_throttle_mae: 0.1428 - learning_rate: 5.0000e-04
# Epoch 30/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1962 - steering_loss: 0.0462 - steering_mae: 0.1280 - throttle_loss: 0.1500 - throttle_mae: 0.1500
# Epoch 30: val_loss improved from 0.19578 to 0.19485, saving model to best_model.keras
#
# Epoch 30: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2034 - steering_loss: 0.0499 - steering_mae: 0.1320 - throttle_loss: 0.1536 - throttle_mae: 0.1535 - val_loss: 0.1949 - val_steering_loss: 0.0537 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1412 - val_throttle_mae: 0.1412 - learning_rate: 5.0000e-04
# Epoch 31/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2000 - steering_loss: 0.0485 - steering_mae: 0.1308 - throttle_loss: 0.1515 - throttle_mae: 0.1515
# Epoch 31: val_loss improved from 0.19485 to 0.19429, saving model to best_model.keras
#
# Epoch 31: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1996 - steering_loss: 0.0500 - steering_mae: 0.1321 - throttle_loss: 0.1498 - throttle_mae: 0.1497 - val_loss: 0.1943 - val_steering_loss: 0.0536 - val_steering_mae: 0.1384 - val_throttle_loss: 0.1407 - val_throttle_mae: 0.1407 - learning_rate: 5.0000e-04
# Epoch 32/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2081 - steering_loss: 0.0520 - steering_mae: 0.1335 - throttle_loss: 0.1561 - throttle_mae: 0.1561
# Epoch 32: val_loss did not improve from 0.19429
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2024 - steering_loss: 0.0498 - steering_mae: 0.1323 - throttle_loss: 0.1526 - throttle_mae: 0.1525 - val_loss: 0.1948 - val_steering_loss: 0.0536 - val_steering_mae: 0.1382 - val_throttle_loss: 0.1412 - val_throttle_mae: 0.1412 - learning_rate: 5.0000e-04
# Epoch 33/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2030 - steering_loss: 0.0494 - steering_mae: 0.1311 - throttle_loss: 0.1536 - throttle_mae: 0.1536
# Epoch 33: val_loss improved from 0.19429 to 0.19280, saving model to best_model.keras
#
# Epoch 33: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2013 - steering_loss: 0.0499 - steering_mae: 0.1322 - throttle_loss: 0.1512 - throttle_mae: 0.1514 - val_loss: 0.1928 - val_steering_loss: 0.0536 - val_steering_mae: 0.1384 - val_throttle_loss: 0.1392 - val_throttle_mae: 0.1391 - learning_rate: 5.0000e-04
# Epoch 34/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2003 - steering_loss: 0.0508 - steering_mae: 0.1328 - throttle_loss: 0.1495 - throttle_mae: 0.1495
# Epoch 34: val_loss improved from 0.19280 to 0.19236, saving model to best_model.keras
#
# Epoch 34: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1991 - steering_loss: 0.0499 - steering_mae: 0.1320 - throttle_loss: 0.1493 - throttle_mae: 0.1493 - val_loss: 0.1924 - val_steering_loss: 0.0538 - val_steering_mae: 0.1388 - val_throttle_loss: 0.1386 - val_throttle_mae: 0.1386 - learning_rate: 5.0000e-04
# Epoch 35/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1959 - steering_loss: 0.0467 - steering_mae: 0.1282 - throttle_loss: 0.1492 - throttle_mae: 0.1492
# Epoch 35: val_loss improved from 0.19236 to 0.19163, saving model to best_model.keras
#
# Epoch 35: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1979 - steering_loss: 0.0499 - steering_mae: 0.1321 - throttle_loss: 0.1479 - throttle_mae: 0.1480 - val_loss: 0.1916 - val_steering_loss: 0.0537 - val_steering_mae: 0.1384 - val_throttle_loss: 0.1379 - val_throttle_mae: 0.1379 - learning_rate: 5.0000e-04
# Epoch 36/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1994 - steering_loss: 0.0497 - steering_mae: 0.1300 - throttle_loss: 0.1497 - throttle_mae: 0.1497
# Epoch 36: val_loss did not improve from 0.19163
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1984 - steering_loss: 0.0499 - steering_mae: 0.1319 - throttle_loss: 0.1484 - throttle_mae: 0.1485 - val_loss: 0.1920 - val_steering_loss: 0.0537 - val_steering_mae: 0.1387 - val_throttle_loss: 0.1383 - val_throttle_mae: 0.1382 - learning_rate: 5.0000e-04
# Epoch 37/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1967 - steering_loss: 0.0508 - steering_mae: 0.1330 - throttle_loss: 0.1458 - throttle_mae: 0.1458
# Epoch 37: val_loss improved from 0.19163 to 0.19094, saving model to best_model.keras
#
# Epoch 37: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1970 - steering_loss: 0.0499 - steering_mae: 0.1317 - throttle_loss: 0.1471 - throttle_mae: 0.1471 - val_loss: 0.1909 - val_steering_loss: 0.0537 - val_steering_mae: 0.1385 - val_throttle_loss: 0.1373 - val_throttle_mae: 0.1373 - learning_rate: 5.0000e-04
# Epoch 38/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1981 - steering_loss: 0.0529 - steering_mae: 0.1350 - throttle_loss: 0.1453 - throttle_mae: 0.1453
# Epoch 38: val_loss did not improve from 0.19094
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1967 - steering_loss: 0.0498 - steering_mae: 0.1316 - throttle_loss: 0.1469 - throttle_mae: 0.1469 - val_loss: 0.1956 - val_steering_loss: 0.0536 - val_steering_mae: 0.1384 - val_throttle_loss: 0.1420 - val_throttle_mae: 0.1420 - learning_rate: 5.0000e-04
# Epoch 39/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1994 - steering_loss: 0.0519 - steering_mae: 0.1345 - throttle_loss: 0.1475 - throttle_mae: 0.1475
# Epoch 39: val_loss improved from 0.19094 to 0.19050, saving model to best_model.keras
#
# Epoch 39: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1979 - steering_loss: 0.0499 - steering_mae: 0.1318 - throttle_loss: 0.1480 - throttle_mae: 0.1480 - val_loss: 0.1905 - val_steering_loss: 0.0535 - val_steering_mae: 0.1382 - val_throttle_loss: 0.1370 - val_throttle_mae: 0.1370 - learning_rate: 5.0000e-04
# Epoch 40/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1944 - steering_loss: 0.0485 - steering_mae: 0.1292 - throttle_loss: 0.1459 - throttle_mae: 0.1459
# Epoch 40: val_loss did not improve from 0.19050
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1959 - steering_loss: 0.0498 - steering_mae: 0.1316 - throttle_loss: 0.1461 - throttle_mae: 0.1461 - val_loss: 0.1913 - val_steering_loss: 0.0535 - val_steering_mae: 0.1380 - val_throttle_loss: 0.1378 - val_throttle_mae: 0.1378 - learning_rate: 5.0000e-04
# Epoch 41/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2092 - steering_loss: 0.0591 - steering_mae: 0.1396 - throttle_loss: 0.1501 - throttle_mae: 0.1501
# Epoch 41: val_loss improved from 0.19050 to 0.19028, saving model to best_model.keras
#
# Epoch 41: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1942 - steering_loss: 0.0495 - steering_mae: 0.1310 - throttle_loss: 0.1446 - throttle_mae: 0.1447 - val_loss: 0.1903 - val_steering_loss: 0.0531 - val_steering_mae: 0.1370 - val_throttle_loss: 0.1372 - val_throttle_mae: 0.1371 - learning_rate: 5.0000e-04
# Epoch 42/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1939 - steering_loss: 0.0479 - steering_mae: 0.1289 - throttle_loss: 0.1460 - throttle_mae: 0.1460
# Epoch 42: val_loss did not improve from 0.19028
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1938 - steering_loss: 0.0492 - steering_mae: 0.1305 - throttle_loss: 0.1446 - throttle_mae: 0.1446 - val_loss: 0.1921 - val_steering_loss: 0.0527 - val_steering_mae: 0.1356 - val_throttle_loss: 0.1394 - val_throttle_mae: 0.1394 - learning_rate: 5.0000e-04
# Epoch 43/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1912 - steering_loss: 0.0497 - steering_mae: 0.1313 - throttle_loss: 0.1415 - throttle_mae: 0.1415
# Epoch 43: val_loss improved from 0.19028 to 0.18769, saving model to best_model.keras
#
# Epoch 43: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1927 - steering_loss: 0.0486 - steering_mae: 0.1294 - throttle_loss: 0.1440 - throttle_mae: 0.1440 - val_loss: 0.1877 - val_steering_loss: 0.0520 - val_steering_mae: 0.1358 - val_throttle_loss: 0.1357 - val_throttle_mae: 0.1356 - learning_rate: 5.0000e-04
# Epoch 44/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1957 - steering_loss: 0.0510 - steering_mae: 0.1318 - throttle_loss: 0.1448 - throttle_mae: 0.1448
# Epoch 44: val_loss improved from 0.18769 to 0.18607, saving model to best_model.keras
#
# Epoch 44: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1919 - steering_loss: 0.0480 - steering_mae: 0.1290 - throttle_loss: 0.1439 - throttle_mae: 0.1439 - val_loss: 0.1861 - val_steering_loss: 0.0507 - val_steering_mae: 0.1325 - val_throttle_loss: 0.1354 - val_throttle_mae: 0.1354 - learning_rate: 5.0000e-04
# Epoch 45/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1863 - steering_loss: 0.0439 - steering_mae: 0.1266 - throttle_loss: 0.1424 - throttle_mae: 0.1424
# Epoch 45: val_loss did not improve from 0.18607
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1906 - steering_loss: 0.0470 - steering_mae: 0.1294 - throttle_loss: 0.1435 - throttle_mae: 0.1435 - val_loss: 0.1861 - val_steering_loss: 0.0492 - val_steering_mae: 0.1306 - val_throttle_loss: 0.1369 - val_throttle_mae: 0.1369 - learning_rate: 5.0000e-04
# Epoch 46/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1932 - steering_loss: 0.0490 - steering_mae: 0.1360 - throttle_loss: 0.1442 - throttle_mae: 0.1442
# Epoch 46: val_loss improved from 0.18607 to 0.18390, saving model to best_model.keras
#
# Epoch 46: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1887 - steering_loss: 0.0466 - steering_mae: 0.1309 - throttle_loss: 0.1423 - throttle_mae: 0.1422 - val_loss: 0.1839 - val_steering_loss: 0.0490 - val_steering_mae: 0.1304 - val_throttle_loss: 0.1349 - val_throttle_mae: 0.1349 - learning_rate: 5.0000e-04
# Epoch 47/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1871 - steering_loss: 0.0470 - steering_mae: 0.1295 - throttle_loss: 0.1402 - throttle_mae: 0.1402
# Epoch 47: val_loss did not improve from 0.18390
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1878 - steering_loss: 0.0461 - steering_mae: 0.1304 - throttle_loss: 0.1417 - throttle_mae: 0.1417 - val_loss: 0.1878 - val_steering_loss: 0.0481 - val_steering_mae: 0.1300 - val_throttle_loss: 0.1397 - val_throttle_mae: 0.1397 - learning_rate: 5.0000e-04
# Epoch 48/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1874 - steering_loss: 0.0445 - steering_mae: 0.1277 - throttle_loss: 0.1430 - throttle_mae: 0.1430
# Epoch 48: val_loss improved from 0.18390 to 0.18286, saving model to best_model.keras
#
# Epoch 48: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1889 - steering_loss: 0.0464 - steering_mae: 0.1309 - throttle_loss: 0.1425 - throttle_mae: 0.1426 - val_loss: 0.1829 - val_steering_loss: 0.0478 - val_steering_mae: 0.1301 - val_throttle_loss: 0.1351 - val_throttle_mae: 0.1351 - learning_rate: 5.0000e-04
# Epoch 49/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1816 - steering_loss: 0.0431 - steering_mae: 0.1276 - throttle_loss: 0.1385 - throttle_mae: 0.1385
# Epoch 49: val_loss did not improve from 0.18286
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1854 - steering_loss: 0.0453 - steering_mae: 0.1300 - throttle_loss: 0.1399 - throttle_mae: 0.1400 - val_loss: 0.1838 - val_steering_loss: 0.0479 - val_steering_mae: 0.1305 - val_throttle_loss: 0.1360 - val_throttle_mae: 0.1360 - learning_rate: 5.0000e-04
# Epoch 50/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1852 - steering_loss: 0.0453 - steering_mae: 0.1326 - throttle_loss: 0.1399 - throttle_mae: 0.1399
# Epoch 50: val_loss improved from 0.18286 to 0.18058, saving model to best_model.keras
#
# Epoch 50: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1856 - steering_loss: 0.0449 - steering_mae: 0.1298 - throttle_loss: 0.1410 - throttle_mae: 0.1408 - val_loss: 0.1806 - val_steering_loss: 0.0465 - val_steering_mae: 0.1296 - val_throttle_loss: 0.1340 - val_throttle_mae: 0.1340 - learning_rate: 5.0000e-04
# Epoch 51/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1846 - steering_loss: 0.0438 - steering_mae: 0.1284 - throttle_loss: 0.1408 - throttle_mae: 0.1408
# Epoch 51: val_loss improved from 0.18058 to 0.17906, saving model to best_model.keras
#
# Epoch 51: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1837 - steering_loss: 0.0442 - steering_mae: 0.1294 - throttle_loss: 0.1394 - throttle_mae: 0.1394 - val_loss: 0.1791 - val_steering_loss: 0.0457 - val_steering_mae: 0.1296 - val_throttle_loss: 0.1334 - val_throttle_mae: 0.1333 - learning_rate: 5.0000e-04
# Epoch 52/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1827 - steering_loss: 0.0429 - steering_mae: 0.1284 - throttle_loss: 0.1398 - throttle_mae: 0.1398
# Epoch 52: val_loss did not improve from 0.17906
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1838 - steering_loss: 0.0442 - steering_mae: 0.1291 - throttle_loss: 0.1397 - throttle_mae: 0.1396 - val_loss: 0.1801 - val_steering_loss: 0.0455 - val_steering_mae: 0.1293 - val_throttle_loss: 0.1346 - val_throttle_mae: 0.1346 - learning_rate: 5.0000e-04
# Epoch 53/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1807 - steering_loss: 0.0423 - steering_mae: 0.1271 - throttle_loss: 0.1384 - throttle_mae: 0.1384
# Epoch 53: val_loss did not improve from 0.17906
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1826 - steering_loss: 0.0433 - steering_mae: 0.1288 - throttle_loss: 0.1391 - throttle_mae: 0.1392 - val_loss: 0.1793 - val_steering_loss: 0.0461 - val_steering_mae: 0.1307 - val_throttle_loss: 0.1332 - val_throttle_mae: 0.1332 - learning_rate: 5.0000e-04
# Epoch 54/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1825 - steering_loss: 0.0466 - steering_mae: 0.1328 - throttle_loss: 0.1360 - throttle_mae: 0.1360
# Epoch 54: val_loss did not improve from 0.17906
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1817 - steering_loss: 0.0429 - steering_mae: 0.1289 - throttle_loss: 0.1386 - throttle_mae: 0.1388 - val_loss: 0.1803 - val_steering_loss: 0.0450 - val_steering_mae: 0.1293 - val_throttle_loss: 0.1353 - val_throttle_mae: 0.1353 - learning_rate: 5.0000e-04
# Epoch 55/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1788 - steering_loss: 0.0419 - steering_mae: 0.1256 - throttle_loss: 0.1369 - throttle_mae: 0.1369
# Epoch 55: val_loss improved from 0.17906 to 0.17749, saving model to best_model.keras
#
# Epoch 55: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1809 - steering_loss: 0.0430 - steering_mae: 0.1282 - throttle_loss: 0.1378 - throttle_mae: 0.1378 - val_loss: 0.1775 - val_steering_loss: 0.0447 - val_steering_mae: 0.1296 - val_throttle_loss: 0.1328 - val_throttle_mae: 0.1328 - learning_rate: 5.0000e-04
# Epoch 56/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1784 - steering_loss: 0.0408 - steering_mae: 0.1262 - throttle_loss: 0.1376 - throttle_mae: 0.1376
# Epoch 56: val_loss did not improve from 0.17749
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1825 - steering_loss: 0.0433 - steering_mae: 0.1303 - throttle_loss: 0.1392 - throttle_mae: 0.1392 - val_loss: 0.1784 - val_steering_loss: 0.0449 - val_steering_mae: 0.1288 - val_throttle_loss: 0.1335 - val_throttle_mae: 0.1335 - learning_rate: 5.0000e-04
# Epoch 57/150
# 53/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1878 - steering_loss: 0.0450 - steering_mae: 0.1304 - throttle_loss: 0.1428 - throttle_mae: 0.1428
# Epoch 57: val_loss did not improve from 0.17749
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1821 - steering_loss: 0.0427 - steering_mae: 0.1281 - throttle_loss: 0.1395 - throttle_mae: 0.1394 - val_loss: 0.1775 - val_steering_loss: 0.0444 - val_steering_mae: 0.1307 - val_throttle_loss: 0.1331 - val_throttle_mae: 0.1331 - learning_rate: 5.0000e-04
# Epoch 58/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1875 - steering_loss: 0.0492 - steering_mae: 0.1384 - throttle_loss: 0.1384 - throttle_mae: 0.1384
# Epoch 58: val_loss did not improve from 0.17749
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1805 - steering_loss: 0.0425 - steering_mae: 0.1294 - throttle_loss: 0.1380 - throttle_mae: 0.1380 - val_loss: 0.1779 - val_steering_loss: 0.0444 - val_steering_mae: 0.1292 - val_throttle_loss: 0.1336 - val_throttle_mae: 0.1336 - learning_rate: 5.0000e-04
# Epoch 59/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1813 - steering_loss: 0.0421 - steering_mae: 0.1275 - throttle_loss: 0.1392 - throttle_mae: 0.1392
# Epoch 59: val_loss improved from 0.17749 to 0.17656, saving model to best_model.keras
#
# Epoch 59: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1802 - steering_loss: 0.0421 - steering_mae: 0.1277 - throttle_loss: 0.1381 - throttle_mae: 0.1381 - val_loss: 0.1766 - val_steering_loss: 0.0438 - val_steering_mae: 0.1292 - val_throttle_loss: 0.1328 - val_throttle_mae: 0.1327 - learning_rate: 5.0000e-04
# Epoch 60/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1770 - steering_loss: 0.0386 - steering_mae: 0.1248 - throttle_loss: 0.1384 - throttle_mae: 0.1384
# Epoch 60: val_loss did not improve from 0.17656
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1793 - steering_loss: 0.0425 - steering_mae: 0.1284 - throttle_loss: 0.1368 - throttle_mae: 0.1368 - val_loss: 0.1767 - val_steering_loss: 0.0442 - val_steering_mae: 0.1286 - val_throttle_loss: 0.1325 - val_throttle_mae: 0.1324 - learning_rate: 5.0000e-04
# Epoch 61/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1801 - steering_loss: 0.0436 - steering_mae: 0.1296 - throttle_loss: 0.1366 - throttle_mae: 0.1366
# Epoch 61: val_loss improved from 0.17656 to 0.17569, saving model to best_model.keras
#
# Epoch 61: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1794 - steering_loss: 0.0424 - steering_mae: 0.1275 - throttle_loss: 0.1371 - throttle_mae: 0.1371 - val_loss: 0.1757 - val_steering_loss: 0.0447 - val_steering_mae: 0.1292 - val_throttle_loss: 0.1310 - val_throttle_mae: 0.1309 - learning_rate: 5.0000e-04
# Epoch 62/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1800 - steering_loss: 0.0436 - steering_mae: 0.1282 - throttle_loss: 0.1364 - throttle_mae: 0.1364
# Epoch 62: val_loss did not improve from 0.17569
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1784 - steering_loss: 0.0421 - steering_mae: 0.1277 - throttle_loss: 0.1363 - throttle_mae: 0.1363 - val_loss: 0.1769 - val_steering_loss: 0.0435 - val_steering_mae: 0.1279 - val_throttle_loss: 0.1334 - val_throttle_mae: 0.1334 - learning_rate: 5.0000e-04
# Epoch 63/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1794 - steering_loss: 0.0427 - steering_mae: 0.1285 - throttle_loss: 0.1367 - throttle_mae: 0.1367
# Epoch 63: val_loss improved from 0.17569 to 0.17473, saving model to best_model.keras
#
# Epoch 63: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1785 - steering_loss: 0.0416 - steering_mae: 0.1269 - throttle_loss: 0.1369 - throttle_mae: 0.1369 - val_loss: 0.1747 - val_steering_loss: 0.0433 - val_steering_mae: 0.1289 - val_throttle_loss: 0.1315 - val_throttle_mae: 0.1314 - learning_rate: 5.0000e-04
# Epoch 64/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1742 - steering_loss: 0.0410 - steering_mae: 0.1279 - throttle_loss: 0.1332 - throttle_mae: 0.1332
# Epoch 64: val_loss improved from 0.17473 to 0.17406, saving model to best_model.keras
#
# Epoch 64: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1776 - steering_loss: 0.0419 - steering_mae: 0.1277 - throttle_loss: 0.1358 - throttle_mae: 0.1358 - val_loss: 0.1741 - val_steering_loss: 0.0432 - val_steering_mae: 0.1292 - val_throttle_loss: 0.1309 - val_throttle_mae: 0.1309 - learning_rate: 5.0000e-04
# Epoch 65/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1697 - steering_loss: 0.0391 - steering_mae: 0.1249 - throttle_loss: 0.1306 - throttle_mae: 0.1306
# Epoch 65: val_loss improved from 0.17406 to 0.17303, saving model to best_model.keras
#
# Epoch 65: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1766 - steering_loss: 0.0411 - steering_mae: 0.1264 - throttle_loss: 0.1357 - throttle_mae: 0.1356 - val_loss: 0.1730 - val_steering_loss: 0.0431 - val_steering_mae: 0.1279 - val_throttle_loss: 0.1299 - val_throttle_mae: 0.1299 - learning_rate: 5.0000e-04
# Epoch 66/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1728 - steering_loss: 0.0390 - steering_mae: 0.1249 - throttle_loss: 0.1339 - throttle_mae: 0.1339
# Epoch 66: val_loss improved from 0.17303 to 0.17202, saving model to best_model.keras
#
# Epoch 66: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1749 - steering_loss: 0.0413 - steering_mae: 0.1274 - throttle_loss: 0.1337 - throttle_mae: 0.1336 - val_loss: 0.1720 - val_steering_loss: 0.0429 - val_steering_mae: 0.1272 - val_throttle_loss: 0.1291 - val_throttle_mae: 0.1291 - learning_rate: 5.0000e-04
# Epoch 67/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1698 - steering_loss: 0.0380 - steering_mae: 0.1210 - throttle_loss: 0.1318 - throttle_mae: 0.1318
# Epoch 67: val_loss improved from 0.17202 to 0.17141, saving model to best_model.keras
#
# Epoch 67: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1750 - steering_loss: 0.0411 - steering_mae: 0.1251 - throttle_loss: 0.1339 - throttle_mae: 0.1339 - val_loss: 0.1714 - val_steering_loss: 0.0429 - val_steering_mae: 0.1282 - val_throttle_loss: 0.1285 - val_throttle_mae: 0.1285 - learning_rate: 5.0000e-04
# Epoch 68/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1686 - steering_loss: 0.0399 - steering_mae: 0.1250 - throttle_loss: 0.1287 - throttle_mae: 0.1287
# Epoch 68: val_loss improved from 0.17141 to 0.16984, saving model to best_model.keras
#
# Epoch 68: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1728 - steering_loss: 0.0408 - steering_mae: 0.1261 - throttle_loss: 0.1320 - throttle_mae: 0.1321 - val_loss: 0.1698 - val_steering_loss: 0.0423 - val_steering_mae: 0.1278 - val_throttle_loss: 0.1276 - val_throttle_mae: 0.1276 - learning_rate: 5.0000e-04
# Epoch 69/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1780 - steering_loss: 0.0449 - steering_mae: 0.1321 - throttle_loss: 0.1331 - throttle_mae: 0.1331
# Epoch 69: val_loss did not improve from 0.16984
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1748 - steering_loss: 0.0413 - steering_mae: 0.1265 - throttle_loss: 0.1335 - throttle_mae: 0.1335 - val_loss: 0.1756 - val_steering_loss: 0.0439 - val_steering_mae: 0.1270 - val_throttle_loss: 0.1318 - val_throttle_mae: 0.1317 - learning_rate: 5.0000e-04
# Epoch 70/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1759 - steering_loss: 0.0446 - steering_mae: 0.1311 - throttle_loss: 0.1313 - throttle_mae: 0.1313
# Epoch 70: val_loss did not improve from 0.16984
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1740 - steering_loss: 0.0405 - steering_mae: 0.1259 - throttle_loss: 0.1335 - throttle_mae: 0.1335 - val_loss: 0.1701 - val_steering_loss: 0.0425 - val_steering_mae: 0.1292 - val_throttle_loss: 0.1276 - val_throttle_mae: 0.1276 - learning_rate: 5.0000e-04
# Epoch 71/150
# 54/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1691 - steering_loss: 0.0404 - steering_mae: 0.1242 - throttle_loss: 0.1287 - throttle_mae: 0.1287
# Epoch 71: val_loss improved from 0.16984 to 0.16962, saving model to best_model.keras
#
# Epoch 71: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1731 - steering_loss: 0.0406 - steering_mae: 0.1261 - throttle_loss: 0.1326 - throttle_mae: 0.1326 - val_loss: 0.1696 - val_steering_loss: 0.0419 - val_steering_mae: 0.1264 - val_throttle_loss: 0.1277 - val_throttle_mae: 0.1277 - learning_rate: 5.0000e-04
# Epoch 72/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1712 - steering_loss: 0.0394 - steering_mae: 0.1241 - throttle_loss: 0.1319 - throttle_mae: 0.1319
# Epoch 72: val_loss improved from 0.16962 to 0.16846, saving model to best_model.keras
#
# Epoch 72: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1746 - steering_loss: 0.0403 - steering_mae: 0.1256 - throttle_loss: 0.1341 - throttle_mae: 0.1342 - val_loss: 0.1685 - val_steering_loss: 0.0418 - val_steering_mae: 0.1272 - val_throttle_loss: 0.1267 - val_throttle_mae: 0.1267 - learning_rate: 5.0000e-04
# Epoch 73/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1696 - steering_loss: 0.0411 - steering_mae: 0.1259 - throttle_loss: 0.1284 - throttle_mae: 0.1284
# Epoch 73: val_loss did not improve from 0.16846
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1713 - steering_loss: 0.0400 - steering_mae: 0.1253 - throttle_loss: 0.1313 - throttle_mae: 0.1313 - val_loss: 0.1718 - val_steering_loss: 0.0420 - val_steering_mae: 0.1264 - val_throttle_loss: 0.1298 - val_throttle_mae: 0.1298 - learning_rate: 5.0000e-04
# Epoch 74/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1730 - steering_loss: 0.0399 - steering_mae: 0.1246 - throttle_loss: 0.1331 - throttle_mae: 0.1331
# Epoch 74: val_loss did not improve from 0.16846
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1726 - steering_loss: 0.0399 - steering_mae: 0.1247 - throttle_loss: 0.1327 - throttle_mae: 0.1328 - val_loss: 0.1701 - val_steering_loss: 0.0418 - val_steering_mae: 0.1249 - val_throttle_loss: 0.1284 - val_throttle_mae: 0.1283 - learning_rate: 5.0000e-04
# Epoch 75/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1695 - steering_loss: 0.0367 - steering_mae: 0.1211 - throttle_loss: 0.1327 - throttle_mae: 0.1327
# Epoch 75: val_loss did not improve from 0.16846
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1721 - steering_loss: 0.0397 - steering_mae: 0.1246 - throttle_loss: 0.1323 - throttle_mae: 0.1323 - val_loss: 0.1687 - val_steering_loss: 0.0414 - val_steering_mae: 0.1257 - val_throttle_loss: 0.1273 - val_throttle_mae: 0.1273 - learning_rate: 5.0000e-04
# Epoch 76/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1697 - steering_loss: 0.0378 - steering_mae: 0.1223 - throttle_loss: 0.1318 - throttle_mae: 0.1318
# Epoch 76: val_loss did not improve from 0.16846
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1711 - steering_loss: 0.0402 - steering_mae: 0.1253 - throttle_loss: 0.1309 - throttle_mae: 0.1309 - val_loss: 0.1714 - val_steering_loss: 0.0434 - val_steering_mae: 0.1291 - val_throttle_loss: 0.1280 - val_throttle_mae: 0.1280 - learning_rate: 5.0000e-04
# Epoch 77/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1682 - steering_loss: 0.0396 - steering_mae: 0.1249 - throttle_loss: 0.1286 - throttle_mae: 0.1286
# Epoch 77: val_loss improved from 0.16846 to 0.16756, saving model to best_model.keras
#
# Epoch 77: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1709 - steering_loss: 0.0398 - steering_mae: 0.1257 - throttle_loss: 0.1311 - throttle_mae: 0.1311 - val_loss: 0.1676 - val_steering_loss: 0.0412 - val_steering_mae: 0.1246 - val_throttle_loss: 0.1264 - val_throttle_mae: 0.1263 - learning_rate: 5.0000e-04
# Epoch 78/150
# 54/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1680 - steering_loss: 0.0382 - steering_mae: 0.1227 - throttle_loss: 0.1298 - throttle_mae: 0.1298
# Epoch 78: val_loss did not improve from 0.16756
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1707 - steering_loss: 0.0393 - steering_mae: 0.1256 - throttle_loss: 0.1315 - throttle_mae: 0.1315 - val_loss: 0.1694 - val_steering_loss: 0.0418 - val_steering_mae: 0.1266 - val_throttle_loss: 0.1276 - val_throttle_mae: 0.1276 - learning_rate: 5.0000e-04
# Epoch 79/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1739 - steering_loss: 0.0414 - steering_mae: 0.1266 - throttle_loss: 0.1324 - throttle_mae: 0.1324
# Epoch 79: val_loss did not improve from 0.16756
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1703 - steering_loss: 0.0396 - steering_mae: 0.1247 - throttle_loss: 0.1306 - throttle_mae: 0.1306 - val_loss: 0.1692 - val_steering_loss: 0.0411 - val_steering_mae: 0.1257 - val_throttle_loss: 0.1282 - val_throttle_mae: 0.1281 - learning_rate: 5.0000e-04
# Epoch 80/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1759 - steering_loss: 0.0415 - steering_mae: 0.1257 - throttle_loss: 0.1344 - throttle_mae: 0.1344
# Epoch 80: val_loss did not improve from 0.16756
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1703 - steering_loss: 0.0399 - steering_mae: 0.1246 - throttle_loss: 0.1303 - throttle_mae: 0.1304 - val_loss: 0.1681 - val_steering_loss: 0.0409 - val_steering_mae: 0.1254 - val_throttle_loss: 0.1272 - val_throttle_mae: 0.1271 - learning_rate: 5.0000e-04
# Epoch 81/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1680 - steering_loss: 0.0390 - steering_mae: 0.1253 - throttle_loss: 0.1290 - throttle_mae: 0.1290
# Epoch 81: val_loss improved from 0.16756 to 0.16619, saving model to best_model.keras
#
# Epoch 81: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1689 - steering_loss: 0.0394 - steering_mae: 0.1248 - throttle_loss: 0.1296 - throttle_mae: 0.1295 - val_loss: 0.1662 - val_steering_loss: 0.0411 - val_steering_mae: 0.1261 - val_throttle_loss: 0.1251 - val_throttle_mae: 0.1251 - learning_rate: 5.0000e-04
# Epoch 82/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1722 - steering_loss: 0.0403 - steering_mae: 0.1247 - throttle_loss: 0.1318 - throttle_mae: 0.1318
# Epoch 82: val_loss improved from 0.16619 to 0.16573, saving model to best_model.keras
#
# Epoch 82: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1694 - steering_loss: 0.0393 - steering_mae: 0.1236 - throttle_loss: 0.1301 - throttle_mae: 0.1301 - val_loss: 0.1657 - val_steering_loss: 0.0409 - val_steering_mae: 0.1260 - val_throttle_loss: 0.1249 - val_throttle_mae: 0.1248 - learning_rate: 5.0000e-04
# Epoch 83/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1736 - steering_loss: 0.0402 - steering_mae: 0.1257 - throttle_loss: 0.1334 - throttle_mae: 0.1334
# Epoch 83: val_loss did not improve from 0.16573
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1700 - steering_loss: 0.0389 - steering_mae: 0.1244 - throttle_loss: 0.1311 - throttle_mae: 0.1310 - val_loss: 0.1687 - val_steering_loss: 0.0409 - val_steering_mae: 0.1251 - val_throttle_loss: 0.1279 - val_throttle_mae: 0.1278 - learning_rate: 5.0000e-04
# Epoch 84/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1751 - steering_loss: 0.0411 - steering_mae: 0.1246 - throttle_loss: 0.1341 - throttle_mae: 0.1341
# Epoch 84: val_loss did not improve from 0.16573
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1690 - steering_loss: 0.0394 - steering_mae: 0.1234 - throttle_loss: 0.1297 - throttle_mae: 0.1297 - val_loss: 0.1669 - val_steering_loss: 0.0405 - val_steering_mae: 0.1239 - val_throttle_loss: 0.1264 - val_throttle_mae: 0.1263 - learning_rate: 5.0000e-04
# Epoch 85/150
# 62/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1703 - steering_loss: 0.0388 - steering_mae: 0.1241 - throttle_loss: 0.1315 - throttle_mae: 0.1315
# Epoch 85: val_loss did not improve from 0.16573
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1680 - steering_loss: 0.0389 - steering_mae: 0.1238 - throttle_loss: 0.1291 - throttle_mae: 0.1292 - val_loss: 0.1662 - val_steering_loss: 0.0410 - val_steering_mae: 0.1235 - val_throttle_loss: 0.1252 - val_throttle_mae: 0.1252 - learning_rate: 5.0000e-04
# Epoch 86/150
# 62/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1638 - steering_loss: 0.0363 - steering_mae: 0.1193 - throttle_loss: 0.1275 - throttle_mae: 0.1275
# Epoch 86: val_loss improved from 0.16573 to 0.16509, saving model to best_model.keras
#
# Epoch 86: finished saving model to best_model.keras
# ...
# Epoch 105/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1669 - steering_loss: 0.0370 - steering_mae: 0.1221 - throttle_loss: 0.1299 - throttle_mae: 0.1299
# Epoch 105: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1653 - steering_loss: 0.0380 - steering_mae: 0.1223 - throttle_loss: 0.1274 - throttle_mae: 0.1274 - val_loss: 0.1629 - val_steering_loss: 0.0392 - val_steering_mae: 0.1197 - val_throttle_loss: 0.1238 - val_throttle_mae: 0.1237 - learning_rate: 5.0000e-04
# Epoch 106/150
# 60/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1635 - steering_loss: 0.0364 - steering_mae: 0.1194 - throttle_loss: 0.1271 - throttle_mae: 0.1271
# Epoch 106: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1656 - steering_loss: 0.0372 - steering_mae: 0.1201 - throttle_loss: 0.1284 - throttle_mae: 0.1285 - val_loss: 0.1631 - val_steering_loss: 0.0392 - val_steering_mae: 0.1199 - val_throttle_loss: 0.1240 - val_throttle_mae: 0.1240 - learning_rate: 5.0000e-04
# Epoch 107/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1617 - steering_loss: 0.0370 - steering_mae: 0.1215 - throttle_loss: 0.1247 - throttle_mae: 0.1247
# Epoch 107: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1652 - steering_loss: 0.0377 - steering_mae: 0.1221 - throttle_loss: 0.1276 - throttle_mae: 0.1275 - val_loss: 0.1652 - val_steering_loss: 0.0391 - val_steering_mae: 0.1204 - val_throttle_loss: 0.1262 - val_throttle_mae: 0.1261 - learning_rate: 5.0000e-04
# Epoch 108/150
# 62/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1730 - steering_loss: 0.0391 - steering_mae: 0.1236 - throttle_loss: 0.1339 - throttle_mae: 0.1339
# Epoch 108: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1654 - steering_loss: 0.0378 - steering_mae: 0.1202 - throttle_loss: 0.1277 - throttle_mae: 0.1277 - val_loss: 0.1656 - val_steering_loss: 0.0413 - val_steering_mae: 0.1228 - val_throttle_loss: 0.1243 - val_throttle_mae: 0.1243 - learning_rate: 5.0000e-04
# Epoch 109/150
# 54/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1619 - steering_loss: 0.0372 - steering_mae: 0.1193 - throttle_loss: 0.1247 - throttle_mae: 0.1247
# Epoch 109: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 109: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1640 - steering_loss: 0.0382 - steering_mae: 0.1212 - throttle_loss: 0.1257 - throttle_mae: 0.1258 - val_loss: 0.1627 - val_steering_loss: 0.0388 - val_steering_mae: 0.1210 - val_throttle_loss: 0.1240 - val_throttle_mae: 0.1239 - learning_rate: 5.0000e-04
# Epoch 110/150
# 62/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1695 - steering_loss: 0.0398 - steering_mae: 0.1244 - throttle_loss: 0.1297 - throttle_mae: 0.1297
# Epoch 110: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1643 - steering_loss: 0.0368 - steering_mae: 0.1203 - throttle_loss: 0.1277 - throttle_mae: 0.1276 - val_loss: 0.1635 - val_steering_loss: 0.0386 - val_steering_mae: 0.1190 - val_throttle_loss: 0.1250 - val_throttle_mae: 0.1250 - learning_rate: 2.5000e-04
# Epoch 111/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1598 - steering_loss: 0.0351 - steering_mae: 0.1171 - throttle_loss: 0.1247 - throttle_mae: 0.1247
# Epoch 111: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1617 - steering_loss: 0.0362 - steering_mae: 0.1190 - throttle_loss: 0.1255 - throttle_mae: 0.1255 - val_loss: 0.1620 - val_steering_loss: 0.0390 - val_steering_mae: 0.1199 - val_throttle_loss: 0.1231 - val_throttle_mae: 0.1231 - learning_rate: 2.5000e-04
# Epoch 112/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1682 - steering_loss: 0.0401 - steering_mae: 0.1227 - throttle_loss: 0.1282 - throttle_mae: 0.1282
# Epoch 112: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1633 - steering_loss: 0.0370 - steering_mae: 0.1203 - throttle_loss: 0.1263 - throttle_mae: 0.1263 - val_loss: 0.1627 - val_steering_loss: 0.0379 - val_steering_mae: 0.1184 - val_throttle_loss: 0.1249 - val_throttle_mae: 0.1248 - learning_rate: 2.5000e-04
# Epoch 113/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1600 - steering_loss: 0.0355 - steering_mae: 0.1150 - throttle_loss: 0.1245 - throttle_mae: 0.1245
# Epoch 113: val_loss did not improve from 0.16183
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1626 - steering_loss: 0.0371 - steering_mae: 0.1194 - throttle_loss: 0.1254 - throttle_mae: 0.1255 - val_loss: 0.1628 - val_steering_loss: 0.0381 - val_steering_mae: 0.1200 - val_throttle_loss: 0.1247 - val_throttle_mae: 0.1247 - learning_rate: 2.5000e-04
# Epoch 114/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1636 - steering_loss: 0.0372 - steering_mae: 0.1206 - throttle_loss: 0.1264 - throttle_mae: 0.1264
# Epoch 114: val_loss improved from 0.16183 to 0.16119, saving model to best_model.keras
#
# Epoch 114: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1624 - steering_loss: 0.0366 - steering_mae: 0.1196 - throttle_loss: 0.1257 - throttle_mae: 0.1258 - val_loss: 0.1612 - val_steering_loss: 0.0381 - val_steering_mae: 0.1197 - val_throttle_loss: 0.1231 - val_throttle_mae: 0.1231 - learning_rate: 2.5000e-04
# Epoch 115/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1604 - steering_loss: 0.0362 - steering_mae: 0.1191 - throttle_loss: 0.1242 - throttle_mae: 0.1242
# Epoch 115: val_loss improved from 0.16119 to 0.16100, saving model to best_model.keras
#
# Epoch 115: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1628 - steering_loss: 0.0372 - steering_mae: 0.1201 - throttle_loss: 0.1256 - throttle_mae: 0.1256 - val_loss: 0.1610 - val_steering_loss: 0.0379 - val_steering_mae: 0.1206 - val_throttle_loss: 0.1232 - val_throttle_mae: 0.1231 - learning_rate: 2.5000e-04
# Epoch 116/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1618 - steering_loss: 0.0372 - steering_mae: 0.1205 - throttle_loss: 0.1246 - throttle_mae: 0.1246
# Epoch 116: val_loss did not improve from 0.16100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1627 - steering_loss: 0.0369 - steering_mae: 0.1202 - throttle_loss: 0.1257 - throttle_mae: 0.1258 - val_loss: 0.1619 - val_steering_loss: 0.0378 - val_steering_mae: 0.1213 - val_throttle_loss: 0.1241 - val_throttle_mae: 0.1241 - learning_rate: 2.5000e-04
# Epoch 117/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1664 - steering_loss: 0.0372 - steering_mae: 0.1191 - throttle_loss: 0.1292 - throttle_mae: 0.1292
# Epoch 117: val_loss did not improve from 0.16100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1629 - steering_loss: 0.0367 - steering_mae: 0.1196 - throttle_loss: 0.1262 - throttle_mae: 0.1262 - val_loss: 0.1611 - val_steering_loss: 0.0380 - val_steering_mae: 0.1199 - val_throttle_loss: 0.1232 - val_throttle_mae: 0.1231 - learning_rate: 2.5000e-04
# Epoch 118/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1628 - steering_loss: 0.0359 - steering_mae: 0.1182 - throttle_loss: 0.1268 - throttle_mae: 0.1268
# Epoch 118: val_loss improved from 0.16100 to 0.16068, saving model to best_model.keras
#
# Epoch 118: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1623 - steering_loss: 0.0367 - steering_mae: 0.1201 - throttle_loss: 0.1255 - throttle_mae: 0.1256 - val_loss: 0.1607 - val_steering_loss: 0.0378 - val_steering_mae: 0.1199 - val_throttle_loss: 0.1229 - val_throttle_mae: 0.1229 - learning_rate: 2.5000e-04
# Epoch 119/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1607 - steering_loss: 0.0345 - steering_mae: 0.1181 - throttle_loss: 0.1262 - throttle_mae: 0.1262
# Epoch 119: val_loss did not improve from 0.16068
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1626 - steering_loss: 0.0367 - steering_mae: 0.1202 - throttle_loss: 0.1259 - throttle_mae: 0.1259 - val_loss: 0.1625 - val_steering_loss: 0.0377 - val_steering_mae: 0.1187 - val_throttle_loss: 0.1248 - val_throttle_mae: 0.1248 - learning_rate: 2.5000e-04
# Epoch 120/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1638 - steering_loss: 0.0345 - steering_mae: 0.1160 - throttle_loss: 0.1293 - throttle_mae: 0.1293
# Epoch 120: val_loss did not improve from 0.16068
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1620 - steering_loss: 0.0361 - steering_mae: 0.1186 - throttle_loss: 0.1259 - throttle_mae: 0.1259 - val_loss: 0.1613 - val_steering_loss: 0.0376 - val_steering_mae: 0.1194 - val_throttle_loss: 0.1238 - val_throttle_mae: 0.1237 - learning_rate: 2.5000e-04
# Epoch 121/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1611 - steering_loss: 0.0360 - steering_mae: 0.1201 - throttle_loss: 0.1251 - throttle_mae: 0.1251
# Epoch 121: val_loss improved from 0.16068 to 0.16051, saving model to best_model.keras
#
# Epoch 121: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1613 - steering_loss: 0.0363 - steering_mae: 0.1190 - throttle_loss: 0.1252 - throttle_mae: 0.1252 - val_loss: 0.1605 - val_steering_loss: 0.0375 - val_steering_mae: 0.1217 - val_throttle_loss: 0.1231 - val_throttle_mae: 0.1230 - learning_rate: 2.5000e-04
# Epoch 122/150
# 56/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1588 - steering_loss: 0.0348 - steering_mae: 0.1179 - throttle_loss: 0.1239 - throttle_mae: 0.1239
# Epoch 122: val_loss improved from 0.16051 to 0.16013, saving model to best_model.keras
#
# Epoch 122: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1609 - steering_loss: 0.0362 - steering_mae: 0.1195 - throttle_loss: 0.1247 - throttle_mae: 0.1247 - val_loss: 0.1601 - val_steering_loss: 0.0378 - val_steering_mae: 0.1205 - val_throttle_loss: 0.1224 - val_throttle_mae: 0.1223 - learning_rate: 2.5000e-04
# Epoch 123/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1610 - steering_loss: 0.0351 - steering_mae: 0.1195 - throttle_loss: 0.1259 - throttle_mae: 0.1259
# Epoch 123: val_loss improved from 0.16013 to 0.15947, saving model to best_model.keras
#
# Epoch 123: finished saving model to best_model.keras
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1617 - steering_loss: 0.0364 - steering_mae: 0.1203 - throttle_loss: 0.1251 - throttle_mae: 0.1252 - val_loss: 0.1595 - val_steering_loss: 0.0375 - val_steering_mae: 0.1198 - val_throttle_loss: 0.1221 - val_throttle_mae: 0.1220 - learning_rate: 2.5000e-04
# Epoch 124/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1611 - steering_loss: 0.0345 - steering_mae: 0.1161 - throttle_loss: 0.1266 - throttle_mae: 0.1266
# Epoch 124: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1618 - steering_loss: 0.0362 - steering_mae: 0.1189 - throttle_loss: 0.1254 - throttle_mae: 0.1255 - val_loss: 0.1619 - val_steering_loss: 0.0382 - val_steering_mae: 0.1196 - val_throttle_loss: 0.1238 - val_throttle_mae: 0.1237 - learning_rate: 2.5000e-04
# Epoch 125/150
# 55/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1597 - steering_loss: 0.0338 - steering_mae: 0.1168 - throttle_loss: 0.1259 - throttle_mae: 0.1259
# Epoch 125: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1620 - steering_loss: 0.0365 - steering_mae: 0.1189 - throttle_loss: 0.1254 - throttle_mae: 0.1255 - val_loss: 0.1606 - val_steering_loss: 0.0377 - val_steering_mae: 0.1216 - val_throttle_loss: 0.1230 - val_throttle_mae: 0.1229 - learning_rate: 2.5000e-04
# Epoch 126/150
# 53/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1581 - steering_loss: 0.0354 - steering_mae: 0.1207 - throttle_loss: 0.1227 - throttle_mae: 0.1227
# Epoch 126: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1615 - steering_loss: 0.0373 - steering_mae: 0.1207 - throttle_loss: 0.1242 - throttle_mae: 0.1243 - val_loss: 0.1626 - val_steering_loss: 0.0389 - val_steering_mae: 0.1183 - val_throttle_loss: 0.1238 - val_throttle_mae: 0.1238 - learning_rate: 2.5000e-04
# Epoch 127/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1620 - steering_loss: 0.0370 - steering_mae: 0.1184 - throttle_loss: 0.1250 - throttle_mae: 0.1250
# Epoch 127: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1625 - steering_loss: 0.0369 - steering_mae: 0.1203 - throttle_loss: 0.1255 - throttle_mae: 0.1256 - val_loss: 0.1619 - val_steering_loss: 0.0376 - val_steering_mae: 0.1190 - val_throttle_loss: 0.1244 - val_throttle_mae: 0.1243 - learning_rate: 2.5000e-04
# Epoch 128/150
# 59/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1647 - steering_loss: 0.0388 - steering_mae: 0.1223 - throttle_loss: 0.1258 - throttle_mae: 0.1258
# Epoch 128: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 128: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1621 - steering_loss: 0.0365 - steering_mae: 0.1194 - throttle_loss: 0.1256 - throttle_mae: 0.1256 - val_loss: 0.1602 - val_steering_loss: 0.0371 - val_steering_mae: 0.1183 - val_throttle_loss: 0.1231 - val_throttle_mae: 0.1230 - learning_rate: 2.5000e-04
# Epoch 129/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1591 - steering_loss: 0.0338 - steering_mae: 0.1155 - throttle_loss: 0.1253 - throttle_mae: 0.1253
# Epoch 129: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1612 - steering_loss: 0.0363 - steering_mae: 0.1182 - throttle_loss: 0.1249 - throttle_mae: 0.1249 - val_loss: 0.1602 - val_steering_loss: 0.0377 - val_steering_mae: 0.1181 - val_throttle_loss: 0.1226 - val_throttle_mae: 0.1225 - learning_rate: 1.2500e-04
# Epoch 130/150
# 57/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1636 - steering_loss: 0.0389 - steering_mae: 0.1225 - throttle_loss: 0.1247 - throttle_mae: 0.1247
# Epoch 130: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1609 - steering_loss: 0.0364 - steering_mae: 0.1192 - throttle_loss: 0.1245 - throttle_mae: 0.1245 - val_loss: 0.1602 - val_steering_loss: 0.0378 - val_steering_mae: 0.1177 - val_throttle_loss: 0.1225 - val_throttle_mae: 0.1224 - learning_rate: 1.2500e-04
# Epoch 131/150
# 63/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1577 - steering_loss: 0.0348 - steering_mae: 0.1168 - throttle_loss: 0.1229 - throttle_mae: 0.1229
# Epoch 131: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1610 - steering_loss: 0.0362 - steering_mae: 0.1188 - throttle_loss: 0.1247 - throttle_mae: 0.1247 - val_loss: 0.1597 - val_steering_loss: 0.0373 - val_steering_mae: 0.1185 - val_throttle_loss: 0.1225 - val_throttle_mae: 0.1224 - learning_rate: 1.2500e-04
# Epoch 132/150
# 58/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1633 - steering_loss: 0.0359 - steering_mae: 0.1175 - throttle_loss: 0.1274 - throttle_mae: 0.1274
# Epoch 132: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1606 - steering_loss: 0.0362 - steering_mae: 0.1188 - throttle_loss: 0.1244 - throttle_mae: 0.1244 - val_loss: 0.1600 - val_steering_loss: 0.0378 - val_steering_mae: 0.1181 - val_throttle_loss: 0.1223 - val_throttle_mae: 0.1222 - learning_rate: 1.2500e-04
# Epoch 133/150
# 61/64 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1575 - steering_loss: 0.0370 - steering_mae: 0.1194 - throttle_loss: 0.1205 - throttle_mae: 0.1205
# Epoch 133: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 133: val_loss did not improve from 0.15947
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1612 - steering_loss: 0.0365 - steering_mae: 0.1195 - throttle_loss: 0.1248 - throttle_mae: 0.1248 - val_loss: 0.1608 - val_steering_loss: 0.0378 - val_steering_mae: 0.1180 - val_throttle_loss: 0.1232 - val_throttle_mae: 0.1231 - learning_rate: 1.2500e-04
# Epoch 133: early stopping
# Restoring model weights from the end of the best epoch: 123.

# %%
import matplotlib.pyplot as plt

def plot_learning_curves(history):
    # ---- Total Loss ----
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"], label="train loss")
    plt.plot(history.history["val_loss"], label="val loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Total Loss")
    plt.legend()
    plt.grid(True)
    6,
    # ---- Output-wise MAE ----
    plt.subplot(1, 2, 2)
    
    for key in history.history.keys():
        if "mae" in key:
            plt.plot(history.history[key], label=key)
    
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.title("Mean Absolute Error per Output")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
plot_learning_curves(history)

# %%
from scipy.stats import spearmanr
import numpy as np
import matplotlib.pyplot as plt

# Get predictions
y_pred = model.predict(X_temp, batch_size=64)

# Handle multi-output model
if isinstance(y_pred, list):  # separate outputs
    y_pred_steering = y_pred[0].ravel()
    y_pred_throttle = y_pred[1].ravel()
    y_pred_combined = np.stack([y_pred_steering, y_pred_throttle], axis=1)
else:  # single concatenated output
    y_pred_combined = y_pred
    y_pred_steering = y_pred[:, 0]
    y_pred_throttle = y_pred[:, 1]

# Compute throttle delta
y_pred_throttle_delta = np.diff(y_pred_throttle, prepend=y_pred_throttle[0])

def plot_pred_vs_gt_with_bins(
    y_true,
    y_pred,
    names=("steering", "throttle"),
    n_bins=20,
):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    for i, ax in enumerate(axes):
        yt = y_true[:, i].ravel()
        yp = y_pred[:, i].ravel()
        
        # Scatter plot
        ax.scatter(yt, yp, s=8, alpha=0.4)
        
        # Perfect prediction line
        lo, hi = yt.min(), yt.max()
        ax.plot([lo, hi], [lo, hi], "r--", label="y = x")
        
        # Correlations
        pearson = np.corrcoef(yt, yp)[0, 1]
        spearman = spearmanr(yt, yp).correlation
        
        # Binned mean prediction
        bins = np.linspace(lo, hi, n_bins + 1)
        bin_centers = 0.5 * (bins[:-1] + bins[1:])
        mean_preds = []
        for b0, b1 in zip(bins[:-1], bins[1:]):
            mask = (yt >= b0) & (yt < b1)
            mean_preds.append(np.mean(yp[mask]) if np.any(mask) else np.nan)
        ax.plot(bin_centers, mean_preds, "k-o", linewidth=2, markersize=4, label="Binned mean pred")
        
        # Annotation
        ax.text(
            0.05,
            0.95,
            f"Pearson r = {pearson:.3f}\nSpearman ρ = {spearman:.3f}",
            transform=ax.transAxes,
            verticalalignment="top",
            bbox=dict(boxstyle="round", facecolor="white", alpha=0.7),
        )
        
        ax.set_xlabel(f"GT {names[i]}")
        ax.set_ylabel(f"Pred {names[i]}")
        ax.set_title(names[i])
        ax.grid(True)
        ax.legend()
    
    plt.tight_layout()
    plt.show()

plot_pred_vs_gt_with_bins(y_temp, y_pred_combined)
def plot_time_series(y_true, y_pred, n_start=None, n_end=None, names=("steering", "throttle")):
    n_samples = len(y_true)
    
    # Auto-detect range if not provided
    if n_start is None:
        n_start = max(0, n_samples - 200)  # Last 200 samples by default
    if n_end is None:
        n_end = n_samples
    
    # Clamp to valid range
    n_start = max(0, min(n_start, n_samples - 1))
    n_end = max(n_start + 1, min(n_end, n_samples))
    
    t = range(n_start, n_end)
    fig, axes = plt.subplots(2, 1, figsize=(10, 6), sharex=True)
    
    for i, ax in enumerate(axes):
        ax.plot(t, y_true[n_start:n_end, i], label="GT", linewidth=2)
        ax.plot(t, y_pred[n_start:n_end, i], label="Pred", linewidth=1)
        ax.set_ylabel(names[i])
        ax.grid(True)
        ax.legend()
    
    axes[0].set_title(f"Time series (samples {n_start}–{n_end})")
    axes[-1].set_xlabel("Frame")
    plt.tight_layout()
    plt.show()

# Now you can call it without arguments
plot_time_series(y_temp, y_pred_combined)



fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Steering distribution
axes[0].hist(y_temp[:, 0], bins=50, alpha=0.5, label='Ground Truth', density=True)
axes[0].hist(y_pred_combined[:, 0], bins=50, alpha=0.5, label='Predictions', density=True)
axes[0].set_xlabel('Steering')
axes[0].set_ylabel('Density')
axes[0].set_title('Steering Distribution')
axes[0].legend()
axes[0].grid(True)

# Throttle distribution
axes[1].hist(y_temp[:, 1], bins=50, alpha=0.5, label='Ground Truth', density=True)
axes[1].hist(y_pred_combined[:, 1], bins=50, alpha=0.5, label='Predictions', density=True)
axes[1].set_xlabel('Throttle')
axes[1].set_ylabel('Density')
axes[1].set_title('Throttle Distribution')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt

def inspect_frame(idx, X, y_true, y_pred):
    """
    idx: sample index
    X: 4D array (N, H, W, C)
    y_true: ground truth array (N, 2)
    y_pred: predicted array or list of arrays
    """
    # Handle multi-output predictions
    if isinstance(y_pred, list):
        y_pred_combined = np.stack([y_pred[0].ravel(), y_pred[1].ravel()], axis=1)
    else:
        y_pred_combined = y_pred

    frame = X[idx, :, :, 0]  # (H, W)
    
    plt.figure(figsize=(4, 4))
    plt.imshow(frame, cmap="viridis", vmin=frame.min(), vmax=frame.max())
    plt.colorbar()
    plt.title(
        f"GT: steer={y_true[idx,0]:.2f}, thr={y_true[idx,1]:.2f}\n"
        f"PR: steer={y_pred_combined[idx,0]:.2f}, thr={y_pred_combined[idx,1]:.2f}"
    )
    plt.axis("off")
    plt.tight_layout()
    plt.show()


# Example usage
inspect_frame(5, X_temp, y_temp, y_pred)
inspect_frame(10, X_temp, y_temp, y_pred)
inspect_frame(15, X_temp, y_temp, y_pred)

# %%
model.save("model.keras")

# %%
def representative_dataset():
    for i in range(len(X_train)):  # Use ALL training data
        yield [X[i:i+1].astype(np.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()

with open("model_int8.tflite", "wb") as f:
    f.write(tflite_model)

print(f"Saved: {len(tflite_model) / 1024:.1f} KB")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpsrfyvqtt/assets
# INFO:tensorflow:Assets written to: /tmp/tmpsrfyvqtt/assets
# Saved artifact at '/tmp/tmpsrfyvqtt'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 24, 24, 10), dtype=tf.float32, name='keras_tensor_930')
# Output Type:
#   List[TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]
# Captures:
#   139716658654928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658645328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658658960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716675019664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658659152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658644944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658655120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658645136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658648976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716658655312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716657819536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716657817808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716657819152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716657815312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139716657819344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718009122128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718009118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718009123856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718009126352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718009119440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718009123664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139718009126544: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/regularpooria/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1771397559.717811   10637 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1771397559.717857   10637 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2026-02-18 01:52:39.718067: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpsrfyvqtt
# 2026-02-18 01:52:39.719005: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2026-02-18 01:52:39.719019: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpsrfyvqtt
# 2026-02-18 01:52:39.726977: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2026-02-18 01:52:39.777670: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpsrfyvqtt
# 2026-02-18 01:52:39.792795: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 74721 microseconds.
# Saved: 31.9 KB
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# 2026-02-18 01:52:40.741178: W tensorflow/compiler/mlir/lite/flatbuffer_export.cc:3705] Skipping runtime version metadata in the model. This will be generated by the exporter.

# %%
interpreter = tf.lite.Interpreter(model_path="model_int8.tflite")
interpreter.allocate_tensors()

in_info = interpreter.get_input_details()[0]
out_info = interpreter.get_output_details()[0]

print("Input shape:", in_info["shape"])
print("Input dtype:", in_info["dtype"])
print("Input quant:", in_info["quantization"])

print("Output dtype:", out_info["dtype"])
print("Output quant:", out_info["quantization"])
# Out:
# Input shape: [ 1 24 24 10]
# Input dtype: <class 'numpy.int8'>
# Input quant: (0.003921568859368563, -128)
# Output dtype: <class 'numpy.int8'>
# Output quant: (0.00390625, -128)
# /home/regularpooria/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# Load original model
model = tf.keras.models.load_model("model.keras")

# Get predictions from both models on validation set
print("Running inference on validation set...")

# Original float model
y_pred_float = model.predict(X_temp, batch_size=64, verbose=0)
steering_float = y_pred_float[0].flatten()
throttle_float = y_pred_float[1].flatten()

# Quantized int8 model
steering_int8_list = []
throttle_int8_list = []

interpreter = tf.lite.Interpreter(model_path="model_int8.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

input_scale, input_zero = input_details[0]['quantization']

# FIXED: Output 0 is THROTTLE, Output 1 is STEERING (swapped!)
throttle_scale, throttle_zero = output_details[0]['quantization']  # Output 0 = throttle
steering_scale, steering_zero = output_details[1]['quantization']  # Output 1 = steering

print(f"\nProcessing {len(X_temp)} validation samples...")
for i in range(len(X_temp)):
    # Quantize input
    test_input = X_temp[i:i+1].astype(np.float32)
    test_input_int8 = (test_input / input_scale + input_zero).astype(np.int8)

    # Run inference
    interpreter.set_tensor(input_details[0]['index'], test_input_int8)
    interpreter.invoke()

    # FIXED: Get outputs in correct order
    throttle_raw = interpreter.get_tensor(output_details[0]['index'])[0][0]  # Output 0 = throttle
    steering_raw = interpreter.get_tensor(output_details[1]['index'])[0][0]  # Output 1 = steering

    # Dequantize
    steering_dequant = (float(steering_raw) - steering_zero) * steering_scale
    throttle_dequant = (float(throttle_raw) - throttle_zero) * throttle_scale

    steering_int8_list.append(steering_dequant)
    throttle_int8_list.append(throttle_dequant)

steering_int8 = np.array(steering_int8_list)
throttle_int8 = np.array(throttle_int8_list)

# Compare predictions
print("\n" + "="*60)
print("COMPARISON: Float Model vs Quantized (int8) Model")
print("="*60)

# Steering comparison
steering_mae = np.mean(np.abs(steering_float - steering_int8))
steering_rmse = np.sqrt(np.mean((steering_float - steering_int8)**2))
steering_corr = np.corrcoef(steering_float, steering_int8)[0, 1]

print(f"\nSTEERING:")
print(f"  MAE (quantization error): {steering_mae:.6f}")
print(f"  RMSE: {steering_rmse:.6f}")
print(f"  Correlation: {steering_corr:.6f}")
print(f"  Float range: [{steering_float.min():.3f}, {steering_float.max():.3f}]")
print(f"  Int8 range:  [{steering_int8.min():.3f}, {steering_int8.max():.3f}]")

# Throttle comparison
throttle_mae = np.mean(np.abs(throttle_float - throttle_int8))
throttle_rmse = np.sqrt(np.mean((throttle_float - throttle_int8)**2))
throttle_corr = np.corrcoef(throttle_float, throttle_int8)[0, 1]

print(f"\nTHROTTLE:")
print(f"  MAE (quantization error): {throttle_mae:.6f}")
print(f"  RMSE: {throttle_rmse:.6f}")
print(f"  Correlation: {throttle_corr:.6f}")
print(f"  Float range: [{throttle_float.min():.3f}, {throttle_float.max():.3f}]")
print(f"  Int8 range:  [{throttle_int8.min():.3f}, {throttle_int8.max():.3f}]")

# Ground truth comparison
print(f"\n" + "="*60)
print("ACCURACY vs Ground Truth (y_val)")
print("="*60)

y_val_steering = y_temp[:, 0]
y_val_throttle = y_temp[:, 1]

print(f"\nFLOAT MODEL:")
print(f"  Steering MAE: {np.mean(np.abs(y_val_steering - steering_float)):.6f}")
print(f"  Throttle MAE: {np.mean(np.abs(y_val_throttle - throttle_float)):.6f}")

print(f"\nQUANTIZED MODEL:")
print(f"  Steering MAE: {np.mean(np.abs(y_val_steering - steering_int8)):.6f}")
print(f"  Throttle MAE: {np.mean(np.abs(y_val_throttle - throttle_int8)):.6f}")

# Rest of visualization code stays the same...

# Visualization
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Steering scatter: Float vs Int8
axes[0, 0].scatter(steering_float, steering_int8, s=1, alpha=0.5)
axes[0, 0].plot([steering_float.min(), steering_float.max()],
                [steering_float.min(), steering_float.max()], 'r--', label='Perfect match')
axes[0, 0].set_xlabel('Float Model')
axes[0, 0].set_ylabel('Quantized Model')
axes[0, 0].set_title(f'Steering: Float vs Int8 (r={steering_corr:.4f})')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Throttle scatter: Float vs Int8
axes[0, 1].scatter(throttle_float, throttle_int8, s=1, alpha=0.5)
axes[0, 1].plot([throttle_float.min(), throttle_float.max()],
                [throttle_float.min(), throttle_float.max()], 'r--', label='Perfect match')
axes[0, 1].set_xlabel('Float Model')
axes[0, 1].set_ylabel('Quantized Model')
axes[0, 1].set_title(f'Throttle: Float vs Int8 (r={throttle_corr:.4f})')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Time series comparison (steering)
n_start, n_end = 1, 300
t = range(n_start, n_end)
axes[1, 0].plot(t, y_val_steering[n_start:n_end], label='Ground Truth', linewidth=2, alpha=0.7)
axes[1, 0].plot(t, steering_float[n_start:n_end], label='Float Model', linewidth=1.5)
axes[1, 0].plot(t, steering_int8[n_start:n_end], label='Quantized Model', linewidth=1, linestyle='--')
axes[1, 0].set_ylabel('Steering')
axes[1, 0].set_title('Steering Time Series')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Time series comparison (throttle)
axes[1, 1].plot(t, y_val_throttle[n_start:n_end], label='Ground Truth', linewidth=2, alpha=0.7)
axes[1, 1].plot(t, throttle_float[n_start:n_end], label='Float Model', linewidth=1.5)
axes[1, 1].plot(t, throttle_int8[n_start:n_end], label='Quantized Model', linewidth=1, linestyle='--')
axes[1, 1].set_ylabel('Throttle')
axes[1, 1].set_title('Throttle Time Series')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Error distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

steering_error = steering_float - steering_int8
throttle_error = throttle_float - throttle_int8

axes[0].hist(steering_error, bins=50, edgecolor='black')
axes[0].set_xlabel('Error (Float - Int8)')
axes[0].set_ylabel('Count')
axes[0].set_title(f'Steering Quantization Error\nMean: {steering_error.mean():.6f}, Std: {steering_error.std():.6f}')
axes[0].grid(True, alpha=0.3)

axes[1].hist(throttle_error, bins=50, edgecolor='black')
axes[1].set_xlabel('Error (Float - Int8)')
axes[1].set_ylabel('Count')
axes[1].set_title(f'Throttle Quantization Error\nMean: {throttle_error.mean():.6f}, Std: {throttle_error.std():.6f}')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Running inference on validation set...
#
# Processing 1021 validation samples...
#
# ============================================================
# COMPARISON: Float Model vs Quantized (int8) Model
# ============================================================
#
# STEERING:
#   MAE (quantization error): 0.004456
#   RMSE: 0.006873
#   Correlation: 0.998639
#   Float range: [-0.599, 0.439]
#   Int8 range:  [-0.602, 0.430]
#
# THROTTLE:
#   MAE (quantization error): 0.006334
#   RMSE: 0.008259
#   Correlation: 0.999146
#   Float range: [0.000, 0.999]
#   Int8 range:  [0.000, 0.996]
#
# ============================================================
# ACCURACY vs Ground Truth (y_val)
# ============================================================
#
# FLOAT MODEL:
#   Steering MAE: 0.113127
#   Throttle MAE: 0.120697
#
# QUANTIZED MODEL:
#   Steering MAE: 0.113029
#   Throttle MAE: 0.120415

# %%
# %%bash
# TFLITE_FILE="model_int8.tflite"
# BASENAME="model"
# SYMBOL="g_model"
# HEADER_GUARD="MODEL_H_"
#
# set -e
#
# # model.cc
# cat > ${BASENAME}.cc <<EOF
# #include "${BASENAME}.h"
#
# alignas(16) const unsigned char ${SYMBOL}[] = {
# EOF
#
# xxd -i ${TFLITE_FILE} \
#   | sed -n '/{/,/}/p' \
#   | sed '1d;$d' \
#   | sed 's/^/  /' \
#   >> ${BASENAME}.cc
#
# cat >> ${BASENAME}.cc <<EOF
# };
#
# const int ${SYMBOL}_len = sizeof(${SYMBOL});
# EOF
#
# # model.h
# cat > ${BASENAME}.h <<EOF
# #ifndef ${HEADER_GUARD}
# #define ${HEADER_GUARD}
#
# extern const unsigned char ${SYMBOL}[];
# extern const int ${SYMBOL}_len;
#
# #endif  // ${HEADER_GUARD}
# EOF
