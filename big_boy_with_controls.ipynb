# %%
# Libraries for data handling and model training
import numpy as np
import pandas as pd

# TensorFlow and Keras for building the CNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2026-02-19 12:23:40.803660: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-19 12:23:40.812215: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-19 12:23:41.177315: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-19 12:23:42.408094: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-19 12:23:42.408363: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Just for context: Logs include a few metadata lines starting with '#', followed by numeric rows.
# Each numeric row layout: frame, steering, throttle, width, height, then 25*25 depth values
paths = [
    "cleaned_60.csv",
    "cleaned_61.csv",
    "cleaned_62.csv",
    "circuit_1.csv",
    "simple_strip.csv",
    "maze.csv",
    "dead_end.csv",
    "more_data.csv",
    "walls_with_gaps.csv",
    "circle_loop_conference.csv"
]
need_to_be_converted = ["walls_with_gaps.csv", "circle_loop_conference.csv"]

H, W = 25, 25
N_DEPTH = H * W

depth_cols = [f"d{i}" for i in range(N_DEPTH)]
col_names = ["frame", "steering", "throttle", "width", "height"] + depth_cols

dfs = []
for p in paths:
    tmp = pd.read_csv(
        p,
        comment="#", # ignore metadata + commented header lines
        header=None, # numeric data has no real header row
        names=col_names # assign stable column names
    )
    if p in need_to_be_converted:
        tmp["steering"] = tmp["steering"].astype(int) / 1000.0
        tmp["throttle"] = tmp["throttle"].astype(int) / 1000.0
    dfs.append(tmp)
df = pd.concat(dfs, ignore_index=True)

# %%
from sklearn.utils import shuffle
import cv2

# Targets: steering + throttle (kept as regression in normalized units)
Y_all = df[["steering", "throttle"]].to_numpy(dtype=np.float32)

# Inputs: depth grid as a single-channel 25x25 image + rotate
X_all = np.rot90(
    df[depth_cols]
      .to_numpy(dtype=np.float32)
      .reshape(-1, H, W, 1),
    k=-1,
    axes=(1, 2)
)
X_all = X_all / 2550

# Resize from 25×25 to target size
def resize_data(X, target_size=(24, 24)):
    """Resize images efficiently"""
    n_samples = X.shape[0]
    X_resized = np.zeros((n_samples, target_size[0], target_size[1], 1), dtype=np.float32)
    
    for i in range(n_samples):
        X_resized[i, :, :, 0] = cv2.resize(
            X[i, :, :, 0], 
            target_size, 
            interpolation=cv2.INTER_AREA  # Best for downsampling
        )
    
    return X_resized
  
# Apply resize
X_all = resize_data(X_all, target_size=(24, 24))
print(X_all.shape)
# Out:
# (37855, 24, 24, 1)

# %%
FRAMES_PER_BLOCK = 20

# %%
def create_blocks(X: np.ndarray, Y: np.ndarray, frame_count: int = 6):
    n = X.shape[0]
    usable = (n // frame_count) * frame_count

    X_trimmed = X[:usable]
    Y_trimmed = Y[:usable]

    # Reshape into blocks
    X_grouped = X_trimmed.reshape(-1, frame_count, *X.shape[1:])
    Y_grouped = Y_trimmed.reshape(-1, frame_count, Y.shape[1])
    # X_grouped: (batch, T, 24, 24, 1)
    # Y_grouped: (batch, T, 2)

    # -----------------
    # TARGET = last frame control
    # -----------------
    Y_out = Y_grouped[:, -1, :]  # (batch, 2)

    # -----------------
    # DEPTH INPUT = all frames (including last)
    # -----------------
    X_depth = np.squeeze(X_grouped, axis=-1)  # (batch, T, 24, 24)
    X_depth = np.transpose(X_depth, (0, 2, 3, 1))
    # (batch, 24, 24, T)

    # -----------------
    # CONTROL HISTORY = all except last
    # -----------------
    ctrl_history = Y_grouped[:, :-1, :]  # (batch, T-1, 2)

    return X_depth, ctrl_history, Y_out


X, C, Y = create_blocks(X_all, Y_all, FRAMES_PER_BLOCK)
print(X.shape)
print(C.shape)
print(Y.shape)
# Out:
# (1892, 24, 24, 20)
# (1892, 19, 2)
# (1892, 2)

# %%
import numpy as np

def mutate_ctrl(
    ctrl,
    zero_prob=0.1,
    noise_prob=0.2,
    steering_noise_std=0.02,
    throttle_noise_std=0.02,
    clip=True
):
    """
    Mutate control history.

    ctrl shape: (batch, frames, 2)
    """

    ctrl_mut = ctrl.copy()
    batch, frames, _ = ctrl_mut.shape

    # Zero entire control pairs at some timesteps
    zero_mask = np.random.rand(batch, frames) < zero_prob
    ctrl_mut[zero_mask] = 0.0

    # Add noise to some timesteps (but not zeroed ones)
    noise_mask = (np.random.rand(batch, frames) < noise_prob) & (~zero_mask)

    steering_noise = np.random.normal(
        0, steering_noise_std, size=(batch, frames)
    )
    throttle_noise = np.random.normal(
        0, throttle_noise_std, size=(batch, frames)
    )

    ctrl_mut[..., 0][noise_mask] += steering_noise[noise_mask]
    ctrl_mut[..., 1][noise_mask] += throttle_noise[noise_mask]

    if clip:
        ctrl_mut = np.clip(ctrl_mut, -1.0, 1.0)

    return ctrl_mut


C = mutate_ctrl(C, zero_prob=0.8, noise_prob=0.1, steering_noise_std=0.1, throttle_noise_std=1)
print(C.shape)
# Out:
# (1892, 19, 2)

# %%
# ---- Create flipped copy ----
X_flip = np.flip(X, axis=2)   # horizontal flip (width axis)

Y_flip = Y.copy()
Y_flip[:, 0] = -Y_flip[:, 0]  # invert steering only

C_flip = C.copy()
C_flip[:, :, 0] = -C_flip[:, :, 0]  # invert steering history


# ---- Append to original ----
X = np.concatenate([X, X_flip], axis=0)
C = np.concatenate([C, C_flip], axis=0)
Y = np.concatenate([Y, Y_flip], axis=0)


# ---- Shuffle the data ----
X, C, Y = shuffle(X, C, Y, random_state=42)


print("X:", X.shape)
print("C:", C.shape)
print("Y:", Y.shape)
print("X normalized min/max:", X.min(), X.max())
print("Y min/max:", Y.min(axis=0), Y.max(axis=0))
# Out:
# X: (3784, 24, 24, 20)
# C: (3784, 19, 2)
# Y: (3784, 2)
# X normalized min/max: 0.023930982 1.0
# Y min/max: [-1. -1.] [1.    0.995]

# %%
from sklearn.model_selection import train_test_split

# First split: train (80%) and temp (20%)
X_train, X_temp, C_train, C_temp, Y_train, Y_temp = train_test_split(
    X, C, Y,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

print("X_train:", X_train.shape)
print("C_train:", C_train.shape)
print("y_train:", Y_train.shape)
# Out:
# X_train: (3027, 24, 24, 20)
# C_train: (3027, 19, 2)
# y_train: (3027, 2)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Show 5 samples
for i in range(100, 105):
    fig, axes = plt.subplots(1, FRAMES_PER_BLOCK, figsize=(30, 3))
    
    for j in range(FRAMES_PER_BLOCK):
        axes[j].imshow(X[i, :, :, j], cmap='gray')
        axes[j].axis("off")
        axes[j].set_title(f"t-{5-j}" if j < 5 else "t")
    
    fig.suptitle(f"Sample {i}")
    plt.tight_layout()
    plt.show()

# %%
import numpy as np

def scheduled_sampling(C_batch, model, X_batch, prob=0.2):
    """
    Occasionally replace past controls with predicted controls.
    
    C_batch: (batch, T-1, 2)
    X_batch: (batch, 24, 24, T)
    prob: fraction of past controls to replace
    """
    C_aug = C_batch.copy()
    
    batch_size, T_minus_1, _ = C_batch.shape

    for i in range(batch_size):
        if np.random.rand() < prob:
            # Predict control for last frame in batch
            ctrl_input = C_aug[i:i+1]      # shape: (1, T-1, 2)
            depth_input = X_batch[i:i+1]   # shape: (1, 24, 24, T)
            
            steering_pred, throttle_pred = model([depth_input, ctrl_input], training=False)
            pred = np.array([steering_pred[0,0], throttle_pred[0,0]])
            
            # Replace last control in history with predicted one
            C_aug[i, -1, :] = pred

    return C_aug

# %%
from tensorflow.keras import layers, Model, Input
from tensorflow.keras.optimizers import Adam

# --------------------------------------------------
# Inputs
# --------------------------------------------------
depth_input = Input(shape=(24, 24, FRAMES_PER_BLOCK), name="depth_input")
ctrl_input = Input(shape=(FRAMES_PER_BLOCK - 1, 2), name="ctrl_input")

# --------------------------------------------------
# CNN Branch (Depth)
# --------------------------------------------------
x = layers.Conv2D(16, 3, strides=2, padding="same", activation="relu6")(depth_input)
x = layers.Conv2D(32, 3, strides=2, padding="same", activation="relu6")(x)
x = layers.Conv2D(32, 3, padding="same", activation="relu6")(x)
x = layers.Conv2D(48, 3, padding="same", activation="relu6")(x)

attention_map = layers.Conv2D(1, 1, activation="sigmoid")(x)
x = layers.Multiply()([x, attention_map])

x = layers.GlobalAveragePooling2D()(x)

# --------------------------------------------------
# Control Branch
# --------------------------------------------------
c = layers.Flatten()(ctrl_input)
c = layers.Dense(32, activation="relu6")(c)

# --------------------------------------------------
# Fusion
# --------------------------------------------------
x = layers.Concatenate()([x, c])

# --------------------------------------------------
# Regression Head
# --------------------------------------------------
x = layers.Dense(64, activation="relu6")(x)
x = layers.Dropout(0.4)(x)

steering_output = layers.Dense(1, activation="tanh", name="steering")(x)
throttle_output = layers.Dense(1, activation="sigmoid", name="throttle")(x)

# --------------------------------------------------
# Model
# --------------------------------------------------
model = Model(
    inputs=[depth_input, ctrl_input],
    outputs=[steering_output, throttle_output]
)

model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss={
        "steering": "mse",
        "throttle": "mae"
    },
    metrics={
        "steering": ["mae"],
        "throttle": ["mae"]
    }
)

model.summary()
# Out:
# 2026-02-19 12:23:46.703713: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ depth_input         │ (None, 24, 24,    │          0 │ -                 │
# │ (InputLayer)        │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 12, 12,    │      2,896 │ depth_input[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 6, 6, 32)  │      4,640 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 6, 6, 32)  │      9,248 │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 6, 6, 48)  │     13,872 │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 6, 6, 1)   │         49 │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ctrl_input          │ (None, 19, 2)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 6, 6, 48)  │          0 │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 38)        │          0 │ ctrl_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ multiply[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        312 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 56)        │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      3,648 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ steering (Dense)    │ (None, 1)         │         65 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ throttle (Dense)    │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 34,795 (135.92 KB)
#  Trainable params: 34,795 (135.92 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
import datetime

# Create callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        'best_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    TensorBoard(
        log_dir=f'logs/{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}',
        histogram_freq=1
    )
]

# import tensorflow as tf
# from tensorflow.keras.optimizers import Adam
# import numpy as np
# import datetime

# # Hyperparameters
# batch_size = 16
# epochs = 150
# scheduled_prob = 0.1  # probability to replace past control with model prediction
# patience = 10         # early stopping patience
# min_delta = 1e-4      # minimum improvement to reset patience

# num_batches = len(X_train) // batch_size

# # Optimizer
# optimizer = Adam(1e-3)

# # TensorBoard
# log_dir = f'logs/custom_loop_{datetime.datetime.now().strftime("%Y%m%d-%H%M%S")}'
# summary_writer = tf.summary.create_file_writer(log_dir)

# best_val_loss = np.inf
# wait = 0

# for epoch in range(epochs):
#     epoch_loss = 0.0
#     num_replaced = 0  # track how many controls replaced by model
#     for step in range(num_batches):
#         start = step * batch_size
#         end = start + batch_size
        
#         X_batch = X_train[start:end].astype(np.float32)
#         C_batch = C_train[start:end].astype(np.float32)
#         y_batch = Y_train[start:end].astype(np.float32)
        
#         # Scheduled sampling
#         replaced_this_batch = 0
#         for i in range(batch_size):
#             if np.random.rand() < scheduled_prob:
#                 s_pred, t_pred = model([X_batch[i:i+1], C_batch[i:i+1]], training=False)
#                 pred = tf.stack([s_pred[0,0], t_pred[0,0]])
#                 C_batch[i, -1, :] = pred
#                 replaced_this_batch += 1
#         num_replaced += replaced_this_batch
        
#         with tf.GradientTape() as tape:
#             s_pred, t_pred = model([X_batch, C_batch], training=True)
#             loss_steer = tf.reduce_mean(tf.square(s_pred - y_batch[:,0:1]))  # MSE
#             loss_throt = tf.reduce_mean(tf.abs(t_pred - y_batch[:,1:2]))      # MAE
#             loss = loss_steer + loss_throt
        
#         grads = tape.gradient(loss, model.trainable_variables)
#         optimizer.apply_gradients(zip(grads, model.trainable_variables))
        
#         epoch_loss += loss.numpy()
    
#     # Average loss for epoch
#     epoch_loss /= num_batches
#     replaced_pct = num_replaced / (num_batches * batch_size)
    
#     # TensorBoard logging
#     with summary_writer.as_default():
#         tf.summary.scalar("train_loss", epoch_loss, step=epoch)
#         tf.summary.scalar("scheduled_sampling_pct", replaced_pct, step=epoch)
    
#     # Optional: simple validation
#     s_val_pred, t_val_pred = model([X_temp.astype(np.float32), C_temp.astype(np.float32)], training=False)
#     val_loss_steer = tf.reduce_mean(tf.square(s_val_pred - Y_temp[:,0:1])).numpy()
#     val_loss_throt = tf.reduce_mean(tf.abs(t_val_pred - Y_temp[:,1:2])).numpy()
#     val_loss = val_loss_steer + val_loss_throt
    
#     with summary_writer.as_default():
#         tf.summary.scalar("val_loss", val_loss, step=epoch)
#         tf.summary.scalar("val_loss_steering", val_loss_steer, step=epoch)
#         tf.summary.scalar("val_loss_throttle", val_loss_throt, step=epoch)
    
#     print(f"Epoch {epoch+1}, train_loss={epoch_loss:.4f}, val_loss={val_loss:.4f}, replaced={replaced_pct*100:.1f}%")
    
#     # Early stopping
#     if val_loss < best_val_loss - min_delta:
#         best_val_loss = val_loss
#         wait = 0
#         # Save best model
#         model.save("best_model.keras")
#     else:
#         wait += 1
#         if wait >= patience:
#             print(f"Early stopping at epoch {epoch+1}")
#             break





# Train using combined control output
history = model.fit(
    [X_train, C_train],
    {
        "steering": Y_train[:, 0],   # First column: steering
        "throttle": Y_train[:, 1]    # Second column: throttle
    },
    validation_data=(
        [X_temp, C_temp], 
        {
            "steering": Y_temp[:, 0],
            "throttle": Y_temp[:, 1]
        }
    ),
    epochs=150,
    batch_size=16,
    callbacks=callbacks
)
# Out:
# Epoch 1/150
# 179/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2490 - steering_loss: 0.0642 - steering_mae: 0.1807 - throttle_loss: 0.1847 - throttle_mae: 0.1847
# Epoch 1: val_loss improved from None to 0.18767, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2127 - steering_loss: 0.0563 - steering_mae: 0.1668 - throttle_loss: 0.1559 - throttle_mae: 0.1562 - val_loss: 0.1877 - val_steering_loss: 0.0419 - val_steering_mae: 0.1331 - val_throttle_loss: 0.1452 - val_throttle_mae: 0.1457 - learning_rate: 0.0010
# Epoch 2/150
# 175/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1987 - steering_loss: 0.0496 - steering_mae: 0.1476 - throttle_loss: 0.1491 - throttle_mae: 0.1491
# Epoch 2: val_loss improved from 0.18767 to 0.17861, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1872 - steering_loss: 0.0453 - steering_mae: 0.1426 - throttle_loss: 0.1415 - throttle_mae: 0.1418 - val_loss: 0.1786 - val_steering_loss: 0.0376 - val_steering_mae: 0.1259 - val_throttle_loss: 0.1402 - val_throttle_mae: 0.1410 - learning_rate: 0.0010
# Epoch 3/150
# 175/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1832 - steering_loss: 0.0439 - steering_mae: 0.1401 - throttle_loss: 0.1393 - throttle_mae: 0.1393
# Epoch 3: val_loss improved from 0.17861 to 0.17479, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1813 - steering_loss: 0.0426 - steering_mae: 0.1365 - throttle_loss: 0.1386 - throttle_mae: 0.1386 - val_loss: 0.1748 - val_steering_loss: 0.0377 - val_steering_mae: 0.1242 - val_throttle_loss: 0.1367 - val_throttle_mae: 0.1370 - learning_rate: 0.0010
# Epoch 4/150
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1740 - steering_loss: 0.0415 - steering_mae: 0.1333 - throttle_loss: 0.1325 - throttle_mae: 0.1325
# Epoch 4: val_loss did not improve from 0.17479
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1747 - steering_loss: 0.0409 - steering_mae: 0.1339 - throttle_loss: 0.1335 - throttle_mae: 0.1337 - val_loss: 0.1758 - val_steering_loss: 0.0367 - val_steering_mae: 0.1297 - val_throttle_loss: 0.1385 - val_throttle_mae: 0.1391 - learning_rate: 0.0010
# Epoch 5/150
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1746 - steering_loss: 0.0405 - steering_mae: 0.1322 - throttle_loss: 0.1341 - throttle_mae: 0.1341
# Epoch 5: val_loss improved from 0.17479 to 0.16662, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1727 - steering_loss: 0.0392 - steering_mae: 0.1312 - throttle_loss: 0.1331 - throttle_mae: 0.1333 - val_loss: 0.1666 - val_steering_loss: 0.0353 - val_steering_mae: 0.1235 - val_throttle_loss: 0.1310 - val_throttle_mae: 0.1313 - learning_rate: 0.0010
# Epoch 6/150
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1680 - steering_loss: 0.0381 - steering_mae: 0.1272 - throttle_loss: 0.1299 - throttle_mae: 0.1299
# Epoch 6: val_loss did not improve from 0.16662
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1641 - steering_loss: 0.0369 - steering_mae: 0.1268 - throttle_loss: 0.1278 - throttle_mae: 0.1271 - val_loss: 0.1723 - val_steering_loss: 0.0372 - val_steering_mae: 0.1255 - val_throttle_loss: 0.1348 - val_throttle_mae: 0.1353 - learning_rate: 0.0010
# Epoch 7/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1698 - steering_loss: 0.0379 - steering_mae: 0.1273 - throttle_loss: 0.1319 - throttle_mae: 0.1319
# Epoch 7: val_loss improved from 0.16662 to 0.16214, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1622 - steering_loss: 0.0359 - steering_mae: 0.1246 - throttle_loss: 0.1263 - throttle_mae: 0.1263 - val_loss: 0.1621 - val_steering_loss: 0.0337 - val_steering_mae: 0.1167 - val_throttle_loss: 0.1284 - val_throttle_mae: 0.1288 - learning_rate: 0.0010
# Epoch 8/150
# 184/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1615 - steering_loss: 0.0374 - steering_mae: 0.1261 - throttle_loss: 0.1241 - throttle_mae: 0.1241
# Epoch 8: val_loss did not improve from 0.16214
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1577 - steering_loss: 0.0342 - steering_mae: 0.1226 - throttle_loss: 0.1230 - throttle_mae: 0.1233 - val_loss: 0.1670 - val_steering_loss: 0.0347 - val_steering_mae: 0.1211 - val_throttle_loss: 0.1323 - val_throttle_mae: 0.1329 - learning_rate: 0.0010
# Epoch 9/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1618 - steering_loss: 0.0371 - steering_mae: 0.1238 - throttle_loss: 0.1248 - throttle_mae: 0.1248
# Epoch 9: val_loss did not improve from 0.16214
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1569 - steering_loss: 0.0334 - steering_mae: 0.1204 - throttle_loss: 0.1229 - throttle_mae: 0.1234 - val_loss: 0.1651 - val_steering_loss: 0.0342 - val_steering_mae: 0.1181 - val_throttle_loss: 0.1304 - val_throttle_mae: 0.1313 - learning_rate: 0.0010
# Epoch 10/150
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1497 - steering_loss: 0.0303 - steering_mae: 0.1168 - throttle_loss: 0.1194 - throttle_mae: 0.1194
# Epoch 10: val_loss did not improve from 0.16214
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1536 - steering_loss: 0.0325 - steering_mae: 0.1182 - throttle_loss: 0.1225 - throttle_mae: 0.1215 - val_loss: 0.1641 - val_steering_loss: 0.0345 - val_steering_mae: 0.1246 - val_throttle_loss: 0.1295 - val_throttle_mae: 0.1304 - learning_rate: 0.0010
# Epoch 11/150
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1491 - steering_loss: 0.0296 - steering_mae: 0.1166 - throttle_loss: 0.1194 - throttle_mae: 0.1194
# Epoch 11: val_loss improved from 0.16214 to 0.15946, saving model to best_model.keras
#
# Epoch 11: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1504 - steering_loss: 0.0301 - steering_mae: 0.1162 - throttle_loss: 0.1202 - throttle_mae: 0.1202 - val_loss: 0.1595 - val_steering_loss: 0.0334 - val_steering_mae: 0.1144 - val_throttle_loss: 0.1267 - val_throttle_mae: 0.1269 - learning_rate: 0.0010
# Epoch 12/150
# 183/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1542 - steering_loss: 0.0339 - steering_mae: 0.1227 - throttle_loss: 0.1203 - throttle_mae: 0.1203
# Epoch 12: val_loss improved from 0.15946 to 0.15603, saving model to best_model.keras
#
# Epoch 12: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1484 - steering_loss: 0.0307 - steering_mae: 0.1174 - throttle_loss: 0.1175 - throttle_mae: 0.1175 - val_loss: 0.1560 - val_steering_loss: 0.0341 - val_steering_mae: 0.1177 - val_throttle_loss: 0.1223 - val_throttle_mae: 0.1227 - learning_rate: 0.0010
# Epoch 13/150
# 176/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1510 - steering_loss: 0.0341 - steering_mae: 0.1192 - throttle_loss: 0.1169 - throttle_mae: 0.1169
# Epoch 13: val_loss improved from 0.15603 to 0.15563, saving model to best_model.keras
#
# Epoch 13: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1451 - steering_loss: 0.0296 - steering_mae: 0.1142 - throttle_loss: 0.1159 - throttle_mae: 0.1155 - val_loss: 0.1556 - val_steering_loss: 0.0339 - val_steering_mae: 0.1166 - val_throttle_loss: 0.1220 - val_throttle_mae: 0.1222 - learning_rate: 0.0010
# Epoch 14/150
# 180/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1369 - steering_loss: 0.0264 - steering_mae: 0.1094 - throttle_loss: 0.1104 - throttle_mae: 0.1104
# Epoch 14: val_loss improved from 0.15563 to 0.15338, saving model to best_model.keras
#
# Epoch 14: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1441 - steering_loss: 0.0311 - steering_mae: 0.1141 - throttle_loss: 0.1149 - throttle_mae: 0.1147 - val_loss: 0.1534 - val_steering_loss: 0.0326 - val_steering_mae: 0.1106 - val_throttle_loss: 0.1210 - val_throttle_mae: 0.1212 - learning_rate: 0.0010
# Epoch 15/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1358 - steering_loss: 0.0287 - steering_mae: 0.1138 - throttle_loss: 0.1070 - throttle_mae: 0.1070
# Epoch 15: val_loss did not improve from 0.15338
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1403 - steering_loss: 0.0283 - steering_mae: 0.1132 - throttle_loss: 0.1122 - throttle_mae: 0.1122 - val_loss: 0.1591 - val_steering_loss: 0.0348 - val_steering_mae: 0.1151 - val_throttle_loss: 0.1242 - val_throttle_mae: 0.1248 - learning_rate: 0.0010
# Epoch 16/150
# 173/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1430 - steering_loss: 0.0295 - steering_mae: 0.1168 - throttle_loss: 0.1136 - throttle_mae: 0.1136
# Epoch 16: val_loss did not improve from 0.15338
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1424 - steering_loss: 0.0302 - steering_mae: 0.1162 - throttle_loss: 0.1139 - throttle_mae: 0.1128 - val_loss: 0.1564 - val_steering_loss: 0.0334 - val_steering_mae: 0.1146 - val_throttle_loss: 0.1230 - val_throttle_mae: 0.1236 - learning_rate: 0.0010
# Epoch 17/150
# 181/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1346 - steering_loss: 0.0265 - steering_mae: 0.1112 - throttle_loss: 0.1081 - throttle_mae: 0.1081
# Epoch 17: val_loss did not improve from 0.15338
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1367 - steering_loss: 0.0268 - steering_mae: 0.1120 - throttle_loss: 0.1093 - throttle_mae: 0.1097 - val_loss: 0.1546 - val_steering_loss: 0.0381 - val_steering_mae: 0.1333 - val_throttle_loss: 0.1174 - val_throttle_mae: 0.1175 - learning_rate: 0.0010
# Epoch 18/150
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1348 - steering_loss: 0.0281 - steering_mae: 0.1140 - throttle_loss: 0.1067 - throttle_mae: 0.1067
# Epoch 18: val_loss did not improve from 0.15338
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1339 - steering_loss: 0.0268 - steering_mae: 0.1117 - throttle_loss: 0.1068 - throttle_mae: 0.1071 - val_loss: 0.1611 - val_steering_loss: 0.0355 - val_steering_mae: 0.1126 - val_throttle_loss: 0.1249 - val_throttle_mae: 0.1255 - learning_rate: 0.0010
# Epoch 19/150
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1299 - steering_loss: 0.0256 - steering_mae: 0.1078 - throttle_loss: 0.1043 - throttle_mae: 0.1043
# Epoch 19: val_loss improved from 0.15338 to 0.15200, saving model to best_model.keras
#
# Epoch 19: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1327 - steering_loss: 0.0263 - steering_mae: 0.1100 - throttle_loss: 0.1065 - throttle_mae: 0.1066 - val_loss: 0.1520 - val_steering_loss: 0.0375 - val_steering_mae: 0.1227 - val_throttle_loss: 0.1144 - val_throttle_mae: 0.1145 - learning_rate: 0.0010
# Epoch 20/150
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1303 - steering_loss: 0.0261 - steering_mae: 0.1089 - throttle_loss: 0.1042 - throttle_mae: 0.1042
# Epoch 20: val_loss improved from 0.15200 to 0.14986, saving model to best_model.keras
#
# Epoch 20: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1304 - steering_loss: 0.0253 - steering_mae: 0.1073 - throttle_loss: 0.1050 - throttle_mae: 0.1051 - val_loss: 0.1499 - val_steering_loss: 0.0363 - val_steering_mae: 0.1158 - val_throttle_loss: 0.1146 - val_throttle_mae: 0.1143 - learning_rate: 0.0010
# Epoch 21/150
# 181/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1315 - steering_loss: 0.0248 - steering_mae: 0.1044 - throttle_loss: 0.1067 - throttle_mae: 0.1067
# Epoch 21: val_loss did not improve from 0.14986
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1287 - steering_loss: 0.0257 - steering_mae: 0.1070 - throttle_loss: 0.1025 - throttle_mae: 0.1029 - val_loss: 0.1527 - val_steering_loss: 0.0330 - val_steering_mae: 0.1117 - val_throttle_loss: 0.1196 - val_throttle_mae: 0.1203 - learning_rate: 0.0010
# Epoch 22/150
# 179/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1210 - steering_loss: 0.0242 - steering_mae: 0.1071 - throttle_loss: 0.0967 - throttle_mae: 0.0967
# Epoch 22: val_loss did not improve from 0.14986
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1255 - steering_loss: 0.0244 - steering_mae: 0.1068 - throttle_loss: 0.1008 - throttle_mae: 0.1010 - val_loss: 0.1600 - val_steering_loss: 0.0426 - val_steering_mae: 0.1272 - val_throttle_loss: 0.1186 - val_throttle_mae: 0.1180 - learning_rate: 0.0010
# Epoch 23/150
# 185/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1281 - steering_loss: 0.0255 - steering_mae: 0.1087 - throttle_loss: 0.1026 - throttle_mae: 0.1026
# Epoch 23: val_loss did not improve from 0.14986
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1266 - steering_loss: 0.0240 - steering_mae: 0.1062 - throttle_loss: 0.1024 - throttle_mae: 0.1026 - val_loss: 0.1633 - val_steering_loss: 0.0338 - val_steering_mae: 0.1136 - val_throttle_loss: 0.1303 - val_throttle_mae: 0.1300 - learning_rate: 0.0010
# Epoch 24/150
# 180/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1233 - steering_loss: 0.0236 - steering_mae: 0.1038 - throttle_loss: 0.0996 - throttle_mae: 0.0996
# Epoch 24: val_loss improved from 0.14986 to 0.14890, saving model to best_model.keras
#
# Epoch 24: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1250 - steering_loss: 0.0247 - steering_mae: 0.1051 - throttle_loss: 0.0999 - throttle_mae: 0.1002 - val_loss: 0.1489 - val_steering_loss: 0.0360 - val_steering_mae: 0.1143 - val_throttle_loss: 0.1135 - val_throttle_mae: 0.1134 - learning_rate: 0.0010
# Epoch 25/150
# 186/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1216 - steering_loss: 0.0216 - steering_mae: 0.1007 - throttle_loss: 0.1000 - throttle_mae: 0.1000
# Epoch 25: val_loss improved from 0.14890 to 0.14396, saving model to best_model.keras
#
# Epoch 25: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1221 - steering_loss: 0.0224 - steering_mae: 0.1024 - throttle_loss: 0.0998 - throttle_mae: 0.0998 - val_loss: 0.1440 - val_steering_loss: 0.0319 - val_steering_mae: 0.1103 - val_throttle_loss: 0.1130 - val_throttle_mae: 0.1132 - learning_rate: 0.0010
# Epoch 26/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1228 - steering_loss: 0.0254 - steering_mae: 0.1068 - throttle_loss: 0.0974 - throttle_mae: 0.0974
# Epoch 26: val_loss improved from 0.14396 to 0.14286, saving model to best_model.keras
#
# Epoch 26: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1231 - steering_loss: 0.0227 - steering_mae: 0.1032 - throttle_loss: 0.1002 - throttle_mae: 0.1003 - val_loss: 0.1429 - val_steering_loss: 0.0319 - val_steering_mae: 0.1112 - val_throttle_loss: 0.1113 - val_throttle_mae: 0.1115 - learning_rate: 0.0010
# Epoch 27/150
# 184/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1193 - steering_loss: 0.0223 - steering_mae: 0.1022 - throttle_loss: 0.0970 - throttle_mae: 0.0970
# Epoch 27: val_loss improved from 0.14286 to 0.14096, saving model to best_model.keras
#
# Epoch 27: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1188 - steering_loss: 0.0230 - steering_mae: 0.1033 - throttle_loss: 0.0955 - throttle_mae: 0.0958 - val_loss: 0.1410 - val_steering_loss: 0.0310 - val_steering_mae: 0.1092 - val_throttle_loss: 0.1100 - val_throttle_mae: 0.1102 - learning_rate: 0.0010
# Epoch 28/150
# 185/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1275 - steering_loss: 0.0282 - steering_mae: 0.1111 - throttle_loss: 0.0992 - throttle_mae: 0.0992
# Epoch 28: val_loss did not improve from 0.14096
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1214 - steering_loss: 0.0249 - steering_mae: 0.1057 - throttle_loss: 0.0963 - throttle_mae: 0.0965 - val_loss: 0.1479 - val_steering_loss: 0.0308 - val_steering_mae: 0.1103 - val_throttle_loss: 0.1180 - val_throttle_mae: 0.1180 - learning_rate: 0.0010
# Epoch 29/150
# 183/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1186 - steering_loss: 0.0225 - steering_mae: 0.1030 - throttle_loss: 0.0961 - throttle_mae: 0.0961
# Epoch 29: val_loss did not improve from 0.14096
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1166 - steering_loss: 0.0228 - steering_mae: 0.1027 - throttle_loss: 0.0936 - throttle_mae: 0.0937 - val_loss: 0.1448 - val_steering_loss: 0.0324 - val_steering_mae: 0.1138 - val_throttle_loss: 0.1131 - val_throttle_mae: 0.1131 - learning_rate: 0.0010
# Epoch 30/150
# 184/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1083 - steering_loss: 0.0187 - steering_mae: 0.0956 - throttle_loss: 0.0895 - throttle_mae: 0.0895
# Epoch 30: val_loss did not improve from 0.14096
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1146 - steering_loss: 0.0216 - steering_mae: 0.0997 - throttle_loss: 0.0930 - throttle_mae: 0.0929 - val_loss: 0.1424 - val_steering_loss: 0.0331 - val_steering_mae: 0.1091 - val_throttle_loss: 0.1097 - val_throttle_mae: 0.1097 - learning_rate: 0.0010
# Epoch 31/150
# 183/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1191 - steering_loss: 0.0236 - steering_mae: 0.1040 - throttle_loss: 0.0955 - throttle_mae: 0.0955
# Epoch 31: val_loss did not improve from 0.14096
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1164 - steering_loss: 0.0234 - steering_mae: 0.1043 - throttle_loss: 0.0935 - throttle_mae: 0.0931 - val_loss: 0.1440 - val_steering_loss: 0.0345 - val_steering_mae: 0.1090 - val_throttle_loss: 0.1094 - val_throttle_mae: 0.1096 - learning_rate: 0.0010
# Epoch 32/150
# 174/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1053 - steering_loss: 0.0199 - steering_mae: 0.0972 - throttle_loss: 0.0854 - throttle_mae: 0.0854
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 32: val_loss did not improve from 0.14096
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1109 - steering_loss: 0.0210 - steering_mae: 0.0999 - throttle_loss: 0.0902 - throttle_mae: 0.0900 - val_loss: 0.1483 - val_steering_loss: 0.0368 - val_steering_mae: 0.1214 - val_throttle_loss: 0.1127 - val_throttle_mae: 0.1123 - learning_rate: 0.0010
# Epoch 33/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1092 - steering_loss: 0.0221 - steering_mae: 0.1017 - throttle_loss: 0.0871 - throttle_mae: 0.0871
# Epoch 33: val_loss improved from 0.14096 to 0.13932, saving model to best_model.keras
#
# Epoch 33: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1068 - steering_loss: 0.0195 - steering_mae: 0.0965 - throttle_loss: 0.0874 - throttle_mae: 0.0873 - val_loss: 0.1393 - val_steering_loss: 0.0323 - val_steering_mae: 0.1084 - val_throttle_loss: 0.1067 - val_throttle_mae: 0.1071 - learning_rate: 5.0000e-04
# Epoch 34/150
# 186/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1068 - steering_loss: 0.0197 - steering_mae: 0.0941 - throttle_loss: 0.0871 - throttle_mae: 0.0871
# Epoch 34: val_loss improved from 0.13932 to 0.13868, saving model to best_model.keras
#
# Epoch 34: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1046 - steering_loss: 0.0188 - steering_mae: 0.0941 - throttle_loss: 0.0857 - throttle_mae: 0.0858 - val_loss: 0.1387 - val_steering_loss: 0.0334 - val_steering_mae: 0.1119 - val_throttle_loss: 0.1051 - val_throttle_mae: 0.1054 - learning_rate: 5.0000e-04
# Epoch 35/150
# 187/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1028 - steering_loss: 0.0188 - steering_mae: 0.0942 - throttle_loss: 0.0841 - throttle_mae: 0.0841
# Epoch 35: val_loss improved from 0.13868 to 0.13739, saving model to best_model.keras
#
# Epoch 35: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1029 - steering_loss: 0.0185 - steering_mae: 0.0933 - throttle_loss: 0.0846 - throttle_mae: 0.0845 - val_loss: 0.1374 - val_steering_loss: 0.0311 - val_steering_mae: 0.1079 - val_throttle_loss: 0.1063 - val_throttle_mae: 0.1065 - learning_rate: 5.0000e-04
# Epoch 36/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0978 - steering_loss: 0.0175 - steering_mae: 0.0918 - throttle_loss: 0.0803 - throttle_mae: 0.0803
# Epoch 36: val_loss did not improve from 0.13739
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1013 - steering_loss: 0.0187 - steering_mae: 0.0942 - throttle_loss: 0.0826 - throttle_mae: 0.0825 - val_loss: 0.1388 - val_steering_loss: 0.0311 - val_steering_mae: 0.1088 - val_throttle_loss: 0.1082 - val_throttle_mae: 0.1081 - learning_rate: 5.0000e-04
# Epoch 37/150
# 184/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1012 - steering_loss: 0.0183 - steering_mae: 0.0928 - throttle_loss: 0.0829 - throttle_mae: 0.0829
# Epoch 37: val_loss did not improve from 0.13739
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1018 - steering_loss: 0.0184 - steering_mae: 0.0939 - throttle_loss: 0.0840 - throttle_mae: 0.0833 - val_loss: 0.1377 - val_steering_loss: 0.0310 - val_steering_mae: 0.1098 - val_throttle_loss: 0.1069 - val_throttle_mae: 0.1070 - learning_rate: 5.0000e-04
# Epoch 38/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0994 - steering_loss: 0.0187 - steering_mae: 0.0945 - throttle_loss: 0.0807 - throttle_mae: 0.0807
# Epoch 38: val_loss improved from 0.13739 to 0.13511, saving model to best_model.keras
#
# Epoch 38: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0992 - steering_loss: 0.0187 - steering_mae: 0.0934 - throttle_loss: 0.0805 - throttle_mae: 0.0805 - val_loss: 0.1351 - val_steering_loss: 0.0299 - val_steering_mae: 0.1104 - val_throttle_loss: 0.1055 - val_throttle_mae: 0.1057 - learning_rate: 5.0000e-04
# Epoch 39/150
# 185/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0965 - steering_loss: 0.0175 - steering_mae: 0.0926 - throttle_loss: 0.0790 - throttle_mae: 0.0790
# Epoch 39: val_loss did not improve from 0.13511
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0979 - steering_loss: 0.0179 - steering_mae: 0.0931 - throttle_loss: 0.0804 - throttle_mae: 0.0800 - val_loss: 0.1364 - val_steering_loss: 0.0317 - val_steering_mae: 0.1059 - val_throttle_loss: 0.1040 - val_throttle_mae: 0.1048 - learning_rate: 5.0000e-04
# Epoch 40/150
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0991 - steering_loss: 0.0192 - steering_mae: 0.0963 - throttle_loss: 0.0799 - throttle_mae: 0.0799
# Epoch 40: val_loss did not improve from 0.13511
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0986 - steering_loss: 0.0181 - steering_mae: 0.0929 - throttle_loss: 0.0804 - throttle_mae: 0.0806 - val_loss: 0.1356 - val_steering_loss: 0.0303 - val_steering_mae: 0.1080 - val_throttle_loss: 0.1055 - val_throttle_mae: 0.1055 - learning_rate: 5.0000e-04
# Epoch 41/150
# 179/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0953 - steering_loss: 0.0183 - steering_mae: 0.0933 - throttle_loss: 0.0770 - throttle_mae: 0.0770
# Epoch 41: val_loss did not improve from 0.13511
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0978 - steering_loss: 0.0180 - steering_mae: 0.0926 - throttle_loss: 0.0808 - throttle_mae: 0.0799 - val_loss: 0.1387 - val_steering_loss: 0.0332 - val_steering_mae: 0.1088 - val_throttle_loss: 0.1054 - val_throttle_mae: 0.1056 - learning_rate: 5.0000e-04
# Epoch 42/150
# 174/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0943 - steering_loss: 0.0169 - steering_mae: 0.0897 - throttle_loss: 0.0774 - throttle_mae: 0.0774
# Epoch 42: val_loss did not improve from 0.13511
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0972 - steering_loss: 0.0180 - steering_mae: 0.0922 - throttle_loss: 0.0791 - throttle_mae: 0.0791 - val_loss: 0.1370 - val_steering_loss: 0.0301 - val_steering_mae: 0.1099 - val_throttle_loss: 0.1071 - val_throttle_mae: 0.1071 - learning_rate: 5.0000e-04
# Epoch 43/150
# 174/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0922 - steering_loss: 0.0172 - steering_mae: 0.0925 - throttle_loss: 0.0750 - throttle_mae: 0.0750
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 43: val_loss did not improve from 0.13511
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0947 - steering_loss: 0.0174 - steering_mae: 0.0922 - throttle_loss: 0.0771 - throttle_mae: 0.0772 - val_loss: 0.1416 - val_steering_loss: 0.0368 - val_steering_mae: 0.1112 - val_throttle_loss: 0.1046 - val_throttle_mae: 0.1046 - learning_rate: 5.0000e-04
# Epoch 44/150
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0935 - steering_loss: 0.0161 - steering_mae: 0.0900 - throttle_loss: 0.0774 - throttle_mae: 0.0774
# Epoch 44: val_loss improved from 0.13511 to 0.13473, saving model to best_model.keras
#
# Epoch 44: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0922 - steering_loss: 0.0167 - steering_mae: 0.0907 - throttle_loss: 0.0757 - throttle_mae: 0.0755 - val_loss: 0.1347 - val_steering_loss: 0.0310 - val_steering_mae: 0.1086 - val_throttle_loss: 0.1038 - val_throttle_mae: 0.1039 - learning_rate: 2.5000e-04
# Epoch 45/150
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0924 - steering_loss: 0.0173 - steering_mae: 0.0928 - throttle_loss: 0.0751 - throttle_mae: 0.0751
# Epoch 45: val_loss improved from 0.13473 to 0.13455, saving model to best_model.keras
#
# Epoch 45: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0903 - steering_loss: 0.0162 - steering_mae: 0.0899 - throttle_loss: 0.0741 - throttle_mae: 0.0741 - val_loss: 0.1346 - val_steering_loss: 0.0303 - val_steering_mae: 0.1070 - val_throttle_loss: 0.1042 - val_throttle_mae: 0.1043 - learning_rate: 2.5000e-04
# Epoch 46/150
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0896 - steering_loss: 0.0165 - steering_mae: 0.0881 - throttle_loss: 0.0731 - throttle_mae: 0.0731
# Epoch 46: val_loss improved from 0.13455 to 0.13230, saving model to best_model.keras
#
# Epoch 46: finished saving model to best_model.keras
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0907 - steering_loss: 0.0168 - steering_mae: 0.0893 - throttle_loss: 0.0753 - throttle_mae: 0.0741 - val_loss: 0.1323 - val_steering_loss: 0.0302 - val_steering_mae: 0.1071 - val_throttle_loss: 0.1020 - val_throttle_mae: 0.1022 - learning_rate: 2.5000e-04
# Epoch 47/150
# 188/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0920 - steering_loss: 0.0171 - steering_mae: 0.0900 - throttle_loss: 0.0750 - throttle_mae: 0.0750
# Epoch 47: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0900 - steering_loss: 0.0169 - steering_mae: 0.0892 - throttle_loss: 0.0732 - throttle_mae: 0.0734 - val_loss: 0.1328 - val_steering_loss: 0.0304 - val_steering_mae: 0.1062 - val_throttle_loss: 0.1020 - val_throttle_mae: 0.1022 - learning_rate: 2.5000e-04
# Epoch 48/150
# 185/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0868 - steering_loss: 0.0158 - steering_mae: 0.0873 - throttle_loss: 0.0710 - throttle_mae: 0.0710
# Epoch 48: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0891 - steering_loss: 0.0164 - steering_mae: 0.0890 - throttle_loss: 0.0726 - throttle_mae: 0.0726 - val_loss: 0.1332 - val_steering_loss: 0.0306 - val_steering_mae: 0.1082 - val_throttle_loss: 0.1024 - val_throttle_mae: 0.1025 - learning_rate: 2.5000e-04
# Epoch 49/150
# 184/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0862 - steering_loss: 0.0152 - steering_mae: 0.0865 - throttle_loss: 0.0710 - throttle_mae: 0.0710
# Epoch 49: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0879 - steering_loss: 0.0158 - steering_mae: 0.0885 - throttle_loss: 0.0723 - throttle_mae: 0.0722 - val_loss: 0.1347 - val_steering_loss: 0.0292 - val_steering_mae: 0.1087 - val_throttle_loss: 0.1057 - val_throttle_mae: 0.1056 - learning_rate: 2.5000e-04
# Epoch 50/150
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0883 - steering_loss: 0.0156 - steering_mae: 0.0881 - throttle_loss: 0.0727 - throttle_mae: 0.0727
# Epoch 50: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0880 - steering_loss: 0.0156 - steering_mae: 0.0873 - throttle_loss: 0.0724 - throttle_mae: 0.0724 - val_loss: 0.1348 - val_steering_loss: 0.0321 - val_steering_mae: 0.1096 - val_throttle_loss: 0.1026 - val_throttle_mae: 0.1025 - learning_rate: 2.5000e-04
# Epoch 51/150
# 186/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0839 - steering_loss: 0.0154 - steering_mae: 0.0884 - throttle_loss: 0.0685 - throttle_mae: 0.0685
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 51: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0869 - steering_loss: 0.0159 - steering_mae: 0.0881 - throttle_loss: 0.0708 - throttle_mae: 0.0710 - val_loss: 0.1344 - val_steering_loss: 0.0305 - val_steering_mae: 0.1072 - val_throttle_loss: 0.1036 - val_throttle_mae: 0.1037 - learning_rate: 2.5000e-04
# Epoch 52/150
# 182/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0849 - steering_loss: 0.0157 - steering_mae: 0.0896 - throttle_loss: 0.0692 - throttle_mae: 0.0692
# Epoch 52: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0849 - steering_loss: 0.0156 - steering_mae: 0.0883 - throttle_loss: 0.0690 - throttle_mae: 0.0692 - val_loss: 0.1328 - val_steering_loss: 0.0304 - val_steering_mae: 0.1063 - val_throttle_loss: 0.1022 - val_throttle_mae: 0.1023 - learning_rate: 1.2500e-04
# Epoch 53/150
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0858 - steering_loss: 0.0164 - steering_mae: 0.0879 - throttle_loss: 0.0694 - throttle_mae: 0.0694
# Epoch 53: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0848 - steering_loss: 0.0154 - steering_mae: 0.0860 - throttle_loss: 0.0696 - throttle_mae: 0.0694 - val_loss: 0.1347 - val_steering_loss: 0.0315 - val_steering_mae: 0.1082 - val_throttle_loss: 0.1031 - val_throttle_mae: 0.1031 - learning_rate: 1.2500e-04
# Epoch 54/150
# 178/190 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0806 - steering_loss: 0.0149 - steering_mae: 0.0863 - throttle_loss: 0.0657 - throttle_mae: 0.0657
# Epoch 54: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0845 - steering_loss: 0.0154 - steering_mae: 0.0860 - throttle_loss: 0.0690 - throttle_mae: 0.0691 - val_loss: 0.1348 - val_steering_loss: 0.0321 - val_steering_mae: 0.1080 - val_throttle_loss: 0.1025 - val_throttle_mae: 0.1025 - learning_rate: 1.2500e-04
# Epoch 55/150
# 180/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0811 - steering_loss: 0.0154 - steering_mae: 0.0875 - throttle_loss: 0.0657 - throttle_mae: 0.0657
# Epoch 55: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0840 - steering_loss: 0.0151 - steering_mae: 0.0863 - throttle_loss: 0.0687 - throttle_mae: 0.0689 - val_loss: 0.1344 - val_steering_loss: 0.0310 - val_steering_mae: 0.1075 - val_throttle_loss: 0.1032 - val_throttle_mae: 0.1032 - learning_rate: 1.2500e-04
# Epoch 56/150
# 183/190 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0834 - steering_loss: 0.0152 - steering_mae: 0.0872 - throttle_loss: 0.0682 - throttle_mae: 0.0682
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 56: val_loss did not improve from 0.13230
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0833 - steering_loss: 0.0153 - steering_mae: 0.0872 - throttle_loss: 0.0683 - throttle_mae: 0.0681 - val_loss: 0.1335 - val_steering_loss: 0.0305 - val_steering_mae: 0.1069 - val_throttle_loss: 0.1028 - val_throttle_mae: 0.1029 - learning_rate: 1.2500e-04
# Epoch 56: early stopping
# Restoring model weights from the end of the best epoch: 46.

# %%
import matplotlib.pyplot as plt

def plot_learning_curves(history):
    # ---- Total Loss ----
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history["loss"], label="train loss")
    plt.plot(history.history["val_loss"], label="val loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Total Loss")
    plt.legend()
    plt.grid(True)
    6,
    # ---- Output-wise MAE ----
    plt.subplot(1, 2, 2)
    
    for key in history.history.keys():
        if "mae" in key:
            plt.plot(history.history[key], label=key)
    
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.title("Mean Absolute Error per Output")
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
plot_learning_curves(history)

# %%
from scipy.stats import spearmanr
import numpy as np
import matplotlib.pyplot as plt

# Get predictions
y_pred = model.predict([X_temp, C_temp], batch_size=64)

# Handle multi-output model
if isinstance(y_pred, list):  # separate outputs
    y_pred_steering = y_pred[0].ravel()
    y_pred_throttle = y_pred[1].ravel()
    y_pred_combined = np.stack([y_pred_steering, y_pred_throttle], axis=1)
else:  # single concatenated output
    y_pred_combined = y_pred
    y_pred_steering = y_pred[:, 0]
    y_pred_throttle = y_pred[:, 1]

# Compute throttle delta
y_pred_throttle_delta = np.diff(y_pred_throttle, prepend=y_pred_throttle[0])

def plot_pred_vs_gt_with_bins(
    y_true,
    y_pred,
    names=("steering", "throttle"),
    n_bins=20,
):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    
    for i, ax in enumerate(axes):
        yt = y_true[:, i].ravel()
        yp = y_pred[:, i].ravel()
        
        # Scatter plot
        ax.scatter(yt, yp, s=8, alpha=0.4)
        
        # Perfect prediction line
        lo, hi = yt.min(), yt.max()
        ax.plot([lo, hi], [lo, hi], "r--", label="y = x")
        
        # Correlations
        pearson = np.corrcoef(yt, yp)[0, 1]
        spearman = spearmanr(yt, yp).correlation
        
        # Binned mean prediction
        bins = np.linspace(lo, hi, n_bins + 1)
        bin_centers = 0.5 * (bins[:-1] + bins[1:])
        mean_preds = []
        for b0, b1 in zip(bins[:-1], bins[1:]):
            mask = (yt >= b0) & (yt < b1)
            mean_preds.append(np.mean(yp[mask]) if np.any(mask) else np.nan)
        ax.plot(bin_centers, mean_preds, "k-o", linewidth=2, markersize=4, label="Binned mean pred")
        
        # Annotation
        ax.text(
            0.05,
            0.95,
            f"Pearson r = {pearson:.3f}\nSpearman ρ = {spearman:.3f}",
            transform=ax.transAxes,
            verticalalignment="top",
            bbox=dict(boxstyle="round", facecolor="white", alpha=0.7),
        )
        
        ax.set_xlabel(f"GT {names[i]}")
        ax.set_ylabel(f"Pred {names[i]}")
        ax.set_title(names[i])
        ax.grid(True)
        ax.legend()
    
    plt.tight_layout()
    plt.show()

plot_pred_vs_gt_with_bins(Y_temp, y_pred_combined)
def plot_time_series(y_true, y_pred, n_start=None, n_end=None, names=("steering", "throttle")):
    n_samples = len(y_true)
    
    # Auto-detect range if not provided
    if n_start is None:
        n_start = max(0, n_samples - 200)  # Last 200 samples by default
    if n_end is None:
        n_end = n_samples
    
    # Clamp to valid range
    n_start = max(0, min(n_start, n_samples - 1))
    n_end = max(n_start + 1, min(n_end, n_samples))
    
    t = range(n_start, n_end)
    fig, axes = plt.subplots(2, 1, figsize=(10, 6), sharex=True)
    
    for i, ax in enumerate(axes):
        ax.plot(t, y_true[n_start:n_end, i], label="GT", linewidth=2)
        ax.plot(t, y_pred[n_start:n_end, i], label="Pred", linewidth=1)
        ax.set_ylabel(names[i])
        ax.grid(True)
        ax.legend()
    
    axes[0].set_title(f"Time series (samples {n_start}–{n_end})")
    axes[-1].set_xlabel("Frame")
    plt.tight_layout()
    plt.show()

# Now you can call it without arguments
plot_time_series(Y_temp, y_pred_combined)



fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Steering distribution
axes[0].hist(Y_temp[:, 0], bins=50, alpha=0.5, label='Ground Truth', density=True)
axes[0].hist(y_pred_combined[:, 0], bins=50, alpha=0.5, label='Predictions', density=True)
axes[0].set_xlabel('Steering')
axes[0].set_ylabel('Density')
axes[0].set_title('Steering Distribution')
axes[0].legend()
axes[0].grid(True)

# Throttle distribution
axes[1].hist(Y_temp[:, 1], bins=50, alpha=0.5, label='Ground Truth', density=True)
axes[1].hist(y_pred_combined[:, 1], bins=50, alpha=0.5, label='Predictions', density=True)
axes[1].set_xlabel('Throttle')
axes[1].set_ylabel('Density')
axes[1].set_title('Throttle Distribution')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
def closed_loop_rollout_range(model, X_all, Y_all, T, start, end):
    """
    Closed-loop rollout between frame indices [start, end).
    """

    preds = []
    gts = []

    # Ensure we have enough past frames
    assert start >= T - 1, "start must be >= T-1"

    # Initialize history from real controls
    ctrl_history = Y_all[start - (T - 1):start].copy()

    for t in range(start, end):

        depth_window = X_all[t - T + 1:t + 1]  # T frames

        depth_window = np.squeeze(depth_window, axis=-1)
        depth_window = np.transpose(depth_window, (1, 2, 0))
        depth_window = np.expand_dims(depth_window, axis=0)

        ctrl_input = np.expand_dims(ctrl_history, axis=0)

        steering_pred, throttle_pred = model(
            [depth_window, ctrl_input],
            training=False
        )

        pred = np.array([steering_pred[0, 0], throttle_pred[0, 0]])

        preds.append(pred)
        gts.append(Y_all[t])

        # Autoregressive update
        ctrl_history = np.vstack([ctrl_history[1:], pred])

    return np.array(preds), np.array(gts)

# %%
import matplotlib.pyplot as plt

# Use closed-loop rollout over a range
preds, gts = closed_loop_rollout_range(model, X_all, Y_all, FRAMES_PER_BLOCK, start=30000, end=30800)

frames = np.arange(30000, 30800)

plt.figure(figsize=(12,5))

# Steering
plt.subplot(2,1,1)
plt.plot(frames, gts[:,0], label='GT Steering')
plt.plot(frames, preds[:,0], label='Pred Steering', alpha=0.7)
plt.ylabel('Steering')
plt.legend()
plt.grid(True)

# Throttle
plt.subplot(2,1,2)
plt.plot(frames, gts[:,1], label='GT Throttle')
plt.plot(frames, preds[:,1], label='Pred Throttle', alpha=0.7)
plt.ylabel('Throttle')
plt.xlabel('Frame')
plt.legend()
plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def inspect_frame(idx, X, y_true, y_pred):
    """
    idx: sample index
    X: 4D array (N, H, W, C)
    y_true: ground truth array (N, 2)
    y_pred: predicted array or list of arrays
    """
    # Handle multi-output predictions
    if isinstance(y_pred, list):
        y_pred_combined = np.stack([y_pred[0].ravel(), y_pred[1].ravel()], axis=1)
    else:
        y_pred_combined = y_pred

    frame = X[idx, :, :, 0]  # (H, W)
    
    plt.figure(figsize=(4, 4))
    plt.imshow(frame, cmap="viridis", vmin=frame.min(), vmax=frame.max())
    plt.colorbar()
    plt.title(
        f"GT: steer={y_true[idx,0]:.2f}, thr={y_true[idx,1]:.2f}\n"
        f"PR: steer={y_pred_combined[idx,0]:.2f}, thr={y_pred_combined[idx,1]:.2f}"
    )
    plt.axis("off")
    plt.tight_layout()
    plt.show()


# Example usage
inspect_frame(5, X_temp, Y_temp, y_pred)
inspect_frame(10, X_temp, Y_temp, y_pred)
inspect_frame(15, X_temp, Y_temp, y_pred)

# %%
model.save("model.keras")

# %%
def representative_dataset():
    for i in range(len(X_train)):  # Use ALL training data
        yield [X[i:i+1].astype(np.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()

with open("model_int8.tflite", "wb") as f:
    f.write(tflite_model)

print(f"Saved: {len(tflite_model) / 1024:.1f} KB")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp80icmvu8/assets
# INFO:tensorflow:Assets written to: /tmp/tmp80icmvu8/assets
# Saved artifact at '/tmp/tmp80icmvu8'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 24, 24, 20), dtype=tf.float32, name='depth_input'), TensorSpec(shape=(None, 19, 2), dtype=tf.float32, name='ctrl_input')]
# Output Type:
#   List[TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]
# Captures:
#   139727846461648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846241488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846241872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846241680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846228048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846718352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846713168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846715856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846718736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846704336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846706064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846704528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846704720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846890512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846888784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846886672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846894736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727846888400: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/regularpooria/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/convert.py:863: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1771521880.206986    5746 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1771521880.207000    5746 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2026-02-19 12:24:40.212530: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp80icmvu8
# 2026-02-19 12:24:40.213179: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2026-02-19 12:24:40.213183: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp80icmvu8
# I0000 00:00:1771521880.218750    5746 mlir_graph_optimization_pass.cc:437] MLIR V1 optimization pass is not enabled
# 2026-02-19 12:24:40.219797: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2026-02-19 12:24:40.259643: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp80icmvu8
# 2026-02-19 12:24:40.269796: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 57268 microseconds.
# 2026-02-19 12:24:40.282984: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 12
#       9 converter.inference_input_type = tf.int8
#      10 converter.inference_output_type = tf.int8
# ---> 12 tflite_model = converter.convert()
#      14 with open("model_int8.tflite", "wb") as f:
#      15     f.write(tflite_model)
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/lite.py:1254, in _export_metrics.<locals>.wrapper(self, *args, **kwargs)
#    1251 @functools.wraps(convert_func)
#    1252 def wrapper(self, *args, **kwargs):
#    1253   # pylint: disable=protected-access
# -> 1254   return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/lite.py:1206, in TFLiteConverterBase._convert_and_export_metrics(self, convert_func, *args, **kwargs)
#    1204 self._save_conversion_params_metric()
#    1205 start_time = time.process_time()
# -> 1206 result = convert_func(self, *args, **kwargs)
#    1207 elapsed_time_ms = (time.process_time() - start_time) * 1000
#    1208 if result:
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/lite.py:1772, in TFLiteKerasModelConverterV2.convert(self)
#    1759 @_export_metrics
#    1760 def convert(self):
#    1761   """Converts a keras model based on instance variables.
#    1762
#    1763   Returns:
#    (...)   1770       Invalid quantization parameters.
#    1771   """
# -> 1772   saved_model_convert_result = self._convert_as_saved_model()
#    1773   if saved_model_convert_result:
#    1774     return saved_model_convert_result
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/lite.py:1753, in TFLiteKerasModelConverterV2._convert_as_saved_model(self)
#    1749   graph_def, input_tensors, output_tensors = (
#    1750       self._convert_keras_to_saved_model(temp_dir)
#    1751   )
#    1752   if self.saved_model_dir:
# -> 1753     return super(TFLiteKerasModelConverterV2, self).convert(
#    1754         graph_def, input_tensors, output_tensors
#    1755     )
#    1756 finally:
#    1757   shutil.rmtree(temp_dir, True)
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/lite.py:1498, in TFLiteConverterBaseV2.convert(self, graph_def, input_tensors, output_tensors)
#    1490 # Converts model.
#    1491 result = _convert_graphdef(
#    1492     input_data=graph_def,
#    1493     input_tensors=input_tensors,
#    1494     output_tensors=output_tensors,
#    1495     **converter_kwargs,
#    1496 )
# -> 1498 return self._optimize_tflite_model(
#    1499     result,
#    1500     self._quant_mode,
#    1501     _build_conversion_flags(**converter_kwargs).debug_options,
#    1502     quant_io=self.experimental_new_quantizer,
#    1503 )
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/convert_phase.py:215, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     213 except Exception as error:
#     214   report_error_message(str(error))
# --> 215   raise error from None
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/lite.py:1150, in TFLiteConverterBase._optimize_tflite_model(self, model, quant_mode, debug_options, quant_io)
#    1148   q_allow_float = quant_mode.is_allow_float()
#    1149   q_variable_quantization = quant_mode.enable_mlir_variable_quantization
# -> 1150   model = self._quantize(
#    1151       model,
#    1152       q_in_type,
#    1153       q_out_type,
#    1154       q_activations_type,
#    1155       q_bias_type,
#    1156       q_allow_float,
#    1157       q_variable_quantization,
#    1158       debug_options,
#    1159   )
#    1161 m_in_type = in_type if in_type else _dtypes.float32
#    1162 m_out_type = out_type if out_type else _dtypes.float32
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/lite.py:761, in TFLiteConverterBase._quantize(self, result, input_type, output_type, activations_type, bias_type, allow_float, enable_variable_quantization, debug_options)
#     757 calibrate_quantize = _calibrator.Calibrator(
#     758     result, custom_op_registerers_by_name, custom_op_registerers_by_func
#     759 )
#     760 if self._experimental_calibrate_only or self.experimental_new_quantizer:
# --> 761   calibrated = calibrate_quantize.calibrate(
#     762       self.representative_dataset.input_gen
#     763   )
#     765 if self._experimental_calibrate_only:
#     766   return calibrated
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/convert_phase.py:215, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     213 except Exception as error:
#     214   report_error_message(str(error))
# --> 215   raise error from None
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/optimize/calibrator.py:258, in Calibrator.calibrate(self, dataset_gen)
#     248 @convert_phase(Component.OPTIMIZE_TFLITE_MODEL, SubComponent.CALIBRATE)
#     249 def calibrate(self, dataset_gen):
#     250   """Calibrates the model with specified generator.
#     251
#     252   Returns:
#    (...)    256     dataset_gen: A generator that generates calibration samples.
#     257   """
# --> 258   self._feed_tensors(dataset_gen, resize_input=True)
#     259   return self._calibrator.Calibrate()
#
# File ~/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/optimize/calibrator.py:143, in Calibrator._feed_tensors(self, dataset_gen, resize_input)
#     139     self._calibrator.Prepare(
#     140         [list(s.shape) for s in input_array], signature_key
#     141     )
#     142   else:
# --> 143     self._calibrator.Prepare([list(s.shape) for s in input_array])
#     144 else:
#     145   if signature_key is not None:
#
# ValueError: Invalid input shapes: expected 2 items got 1 items.

# %%
interpreter = tf.lite.Interpreter(model_path="model_int8.tflite")
interpreter.allocate_tensors()

in_info = interpreter.get_input_details()[0]
out_info = interpreter.get_output_details()[0]

print("Input shape:", in_info["shape"])
print("Input dtype:", in_info["dtype"])
print("Input quant:", in_info["quantization"])

print("Output dtype:", out_info["dtype"])
print("Output quant:", out_info["quantization"])

from tensorflow.lite.python import analyzer

with open("model_int8.tflite", "rb") as f:
    model_content = f.read()

print(analyzer.ModelAnalyzer.analyze(
    model_content=model_content,
    gpu_compatibility=False))
# Out:
# Input shape: [ 1 24 24 20]
# Input dtype: <class 'numpy.int8'>
# Input quant: (0.003921568859368563, -128)
# Output dtype: <class 'numpy.int8'>
# Output quant: (0.00390625, -128)
# === TFLite ModelAnalyzer ===
#
# Your TFLite model has '1' subgraph(s). In the subgraph description below,
# T# represents the Tensor numbers. For example, in Subgraph#0, the CONV_2D op takes
# tensor #0 and tensor #17 and tensor #16 as input and produces tensor #18 as output.
#
# Subgraph#0 main(T#0) -> [T#30, T#28]
#   Op#0 CONV_2D(T#0, T#17, T#16[-56405, -39550, -3286, 4945, -3377, ...]) -> [T#18]
#   Op#1 CONV_2D(T#18, T#15, T#14[-2914, 27, -297, -3479, -5518, ...]) -> [T#19]
#   Op#2 CONV_2D(T#19, T#13, T#12[-1614, 226, -895, -825, -114, ...]) -> [T#20]
#   Op#3 CONV_2D(T#20, T#11, T#10[-590, 642, -1578, 28, -1404, ...]) -> [T#21]
#   Op#4 CONV_2D(T#21, T#9, T#8[149]) -> [T#22]
#   Op#5 LOGISTIC(T#22) -> [T#23]
#   Op#6 MUL(T#21, T#23) -> [T#24]
#   Op#7 MEAN(T#24, T#1[1, 2]) -> [T#25]
#   Op#8 FULLY_CONNECTED(T#25, T#7, T#6[-2483, -5100, 0, 670, -3214, ...]) -> [T#26]
#   Op#9 FULLY_CONNECTED(T#26, T#5, T#4[-100]) -> [T#27]
#   Op#10 TANH(T#27) -> [T#28]
#   Op#11 FULLY_CONNECTED(T#26, T#3, T#2[7256]) -> [T#29]
#   Op#12 LOGISTIC(T#29) -> [T#30]
#
# Tensors of Subgraph#0
#   T#0(serving_default_keras_tensor_208:0) shape_signature:[-1, 24, 24, 20], type:INT8
#   T#1(arith.constant) shape:[2], type:INT32 RO 8 bytes, buffer: 2, data:[1, 2]
#   T#2(tfl.pseudo_qconst) shape:[1], type:INT32 RO 4 bytes, buffer: 3, data:[7256]
#   T#3(tfl.pseudo_qconst1) shape:[1, 48], type:INT8 RO 48 bytes, buffer: 4, data:[., :, ., ., E, ...]
#   T#4(tfl.pseudo_qconst2) shape:[1], type:INT32 RO 4 bytes, buffer: 5, data:[-100]
#   T#5(tfl.pseudo_qconst3) shape:[1, 48], type:INT8 RO 48 bytes, buffer: 6, data:[., ., E, ., ., ...]
#   T#6(tfl.pseudo_qconst4) shape:[48], type:INT32 RO 192 bytes, buffer: 7, data:[-2483, -5100, 0, 670, -3214, ...]
#   T#7(tfl.pseudo_qconst5) shape:[48, 48], type:INT8 RO 2304 bytes, buffer: 8, data:[., @, ., ., ., ...]
#   T#8(tfl.pseudo_qconst6) shape:[1], type:INT32 RO 4 bytes, buffer: 9, data:[149]
#   T#9(tfl.pseudo_qconst7) shape:[1, 1, 1, 48], type:INT8 RO 48 bytes, buffer: 10, data:[D, y, 3, w, ., ...]
#   T#10(tfl.pseudo_qconst8) shape:[48], type:INT32 RO 192 bytes, buffer: 11, data:[-590, 642, -1578, 28, -1404, ...]
#   T#11(tfl.pseudo_qconst9) shape:[48, 3, 3, 32], type:INT8 RO 13824 bytes, buffer: 12, data:[., ., ", ., ., ...]
#   T#12(tfl.pseudo_qconst10) shape:[32], type:INT32 RO 128 bytes, buffer: 13, data:[-1614, 226, -895, -825, -114, ...]
#   T#13(tfl.pseudo_qconst11) shape:[32, 3, 3, 32], type:INT8 RO 9216 bytes, buffer: 14, data:[., ., ", ., ., ...]
#   T#14(tfl.pseudo_qconst12) shape:[32], type:INT32 RO 128 bytes, buffer: 15, data:[-2914, 27, -297, -3479, -5518, ...]
#   T#15(tfl.pseudo_qconst13) shape:[32, 3, 3, 16], type:INT8 RO 4608 bytes, buffer: 16, data:[:, ., ., ., ., ...]
#   T#16(tfl.pseudo_qconst14) shape:[16], type:INT32 RO 64 bytes, buffer: 17, data:[-56405, -39550, -3286, 4945, -3377, ...]
#   T#17(tfl.pseudo_qconst15) shape:[16, 3, 3, 20], type:INT8 RO 2880 bytes, buffer: 18, data:[., 9, ., ., ., ...]
#   T#18(functional_10_1/conv2d_50_1/Relu6;functional_10_1/conv2d_50_1/BiasAdd;functional_10_1/conv2d_50_1/convolution;functional_10_1/conv2d_50_1/Squeeze1) shape_signature:[-1, 12, 12, 16], type:INT8
#   T#19(functional_10_1/conv2d_51_1/Relu6;functional_10_1/conv2d_51_1/BiasAdd;functional_10_1/conv2d_51_1/convolution;functional_10_1/conv2d_51_1/Squeeze) shape_signature:[-1, 6, 6, 32], type:INT8
#   T#20(functional_10_1/conv2d_52_1/Relu6;functional_10_1/conv2d_52_1/BiasAdd;functional_10_1/conv2d_52_1/convolution;functional_10_1/conv2d_52_1/Squeeze) shape_signature:[-1, 6, 6, 32], type:INT8
#   T#21(functional_10_1/conv2d_53_1/Relu6;functional_10_1/conv2d_53_1/BiasAdd;functional_10_1/conv2d_53_1/convolution;functional_10_1/conv2d_53_1/Squeeze) shape_signature:[-1, 6, 6, 48], type:INT8
#   T#22(functional_10_1/conv2d_54_1/Add;functional_10_1/conv2d_54_1/convolution;functional_10_1/conv2d_54_1/Reshape) shape_signature:[-1, 6, 6, 1], type:INT8
#   T#23(functional_10_1/conv2d_54_1/Sigmoid) shape_signature:[-1, 6, 6, 1], type:INT8
#   T#24(functional_10_1/multiply_10_1/Mul) shape_signature:[-1, 6, 6, 48], type:INT8
#   T#25(functional_10_1/global_average_pooling2d_14_1/Mean) shape_signature:[-1, 48], type:INT8
#   T#26(functional_10_1/dense_10_1/MatMul;functional_10_1/dense_10_1/Relu6;functional_10_1/dense_10_1/BiasAdd) shape_signature:[-1, 48], type:INT8
#   T#27(functional_10_1/steering_1/MatMul;functional_10_1/steering_1/Add) shape_signature:[-1, 1], type:INT8
#   T#28(StatefulPartitionedCall_1:0) shape_signature:[-1, 1], type:INT8
#   T#29(functional_10_1/throttle_1/MatMul;functional_10_1/throttle_1/Add) shape_signature:[-1, 1], type:INT8
#   T#30(StatefulPartitionedCall_1:1) shape_signature:[-1, 1], type:INT8
#
# ---------------------------------------------------------------
# Your TFLite model has '1' signature_def(s).
#
# Signature#0 key: 'serving_default'
# - Subgraph: Subgraph#0
# - Inputs:
#     'keras_tensor_208' : T#0
# - Outputs:
#     'output_0' : T#28
#     'output_1' : T#30
#
# ---------------------------------------------------------------
#               Model size:      44112 bytes
#     Non-data buffer size:      10300 bytes (23.35 %)
#   Total data buffer size:      33812 bytes (76.65 %)
#     (Zero value buffers):          0 bytes (00.00 %)
#
# * Buffers of TFLite model are mostly used for constant tensors.
#   And zero value buffers are buffers filled with zeros.
#   Non-data buffers area are used to store operators, subgraphs and etc.
#   You can find more details from https://github.com/tensorflow/tensorflow/blob/master/tensorflow/lite/schema/schema.fbs
#
# None
# /home/regularpooria/Projects/tinynav_cnn/venv/lib64/python3.13/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# Load original model
model = tf.keras.models.load_model("model.keras")

# Get predictions from both models on validation set
print("Running inference on validation set...")

# Original float model
y_pred_float = model.predict(X_temp, batch_size=64, verbose=0)
steering_float = y_pred_float[0].flatten()
throttle_float = y_pred_float[1].flatten()

# Quantized int8 model
steering_int8_list = []
throttle_int8_list = []

interpreter = tf.lite.Interpreter(model_path="model_int8.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

input_scale, input_zero = input_details[0]['quantization']

# FIXED: Output 0 is THROTTLE, Output 1 is STEERING (swapped!)
throttle_scale, throttle_zero = output_details[0]['quantization']  # Output 0 = throttle
steering_scale, steering_zero = output_details[1]['quantization']  # Output 1 = steering

print(f"\nProcessing {len(X_temp)} validation samples...")
for i in range(len(X_temp)):
    # Quantize input
    test_input = X_temp[i:i+1].astype(np.float32)
    test_input_int8 = (test_input / input_scale + input_zero).astype(np.int8)

    # Run inference
    interpreter.set_tensor(input_details[0]['index'], test_input_int8)
    interpreter.invoke()

    # FIXED: Get outputs in correct order
    throttle_raw = interpreter.get_tensor(output_details[0]['index'])[0][0]  # Output 0 = throttle
    steering_raw = interpreter.get_tensor(output_details[1]['index'])[0][0]  # Output 1 = steering

    # Dequantize
    steering_dequant = (float(steering_raw) - steering_zero) * steering_scale
    throttle_dequant = (float(throttle_raw) - throttle_zero) * throttle_scale

    steering_int8_list.append(steering_dequant)
    throttle_int8_list.append(throttle_dequant)

steering_int8 = np.array(steering_int8_list)
throttle_int8 = np.array(throttle_int8_list)

# Compare predictions
print("\n" + "="*60)
print("COMPARISON: Float Model vs Quantized (int8) Model")
print("="*60)

# Steering comparison
steering_mae = np.mean(np.abs(steering_float - steering_int8))
steering_rmse = np.sqrt(np.mean((steering_float - steering_int8)**2))
steering_corr = np.corrcoef(steering_float, steering_int8)[0, 1]

print(f"\nSTEERING:")
print(f"  MAE (quantization error): {steering_mae:.6f}")
print(f"  RMSE: {steering_rmse:.6f}")
print(f"  Correlation: {steering_corr:.6f}")
print(f"  Float range: [{steering_float.min():.3f}, {steering_float.max():.3f}]")
print(f"  Int8 range:  [{steering_int8.min():.3f}, {steering_int8.max():.3f}]")

# Throttle comparison
throttle_mae = np.mean(np.abs(throttle_float - throttle_int8))
throttle_rmse = np.sqrt(np.mean((throttle_float - throttle_int8)**2))
throttle_corr = np.corrcoef(throttle_float, throttle_int8)[0, 1]

print(f"\nTHROTTLE:")
print(f"  MAE (quantization error): {throttle_mae:.6f}")
print(f"  RMSE: {throttle_rmse:.6f}")
print(f"  Correlation: {throttle_corr:.6f}")
print(f"  Float range: [{throttle_float.min():.3f}, {throttle_float.max():.3f}]")
print(f"  Int8 range:  [{throttle_int8.min():.3f}, {throttle_int8.max():.3f}]")

# Ground truth comparison
print(f"\n" + "="*60)
print("ACCURACY vs Ground Truth (y_val)")
print("="*60)

y_val_steering = Y_temp[:, 0]
y_val_throttle = Y_temp[:, 1]

print(f"\nFLOAT MODEL:")
print(f"  Steering MAE: {np.mean(np.abs(y_val_steering - steering_float)):.6f}")
print(f"  Throttle MAE: {np.mean(np.abs(y_val_throttle - throttle_float)):.6f}")

print(f"\nQUANTIZED MODEL:")
print(f"  Steering MAE: {np.mean(np.abs(y_val_steering - steering_int8)):.6f}")
print(f"  Throttle MAE: {np.mean(np.abs(y_val_throttle - throttle_int8)):.6f}")

# Rest of visualization code stays the same...

# Visualization
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Steering scatter: Float vs Int8
axes[0, 0].scatter(steering_float, steering_int8, s=1, alpha=0.5)
axes[0, 0].plot([steering_float.min(), steering_float.max()],
                [steering_float.min(), steering_float.max()], 'r--', label='Perfect match')
axes[0, 0].set_xlabel('Float Model')
axes[0, 0].set_ylabel('Quantized Model')
axes[0, 0].set_title(f'Steering: Float vs Int8 (r={steering_corr:.4f})')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Throttle scatter: Float vs Int8
axes[0, 1].scatter(throttle_float, throttle_int8, s=1, alpha=0.5)
axes[0, 1].plot([throttle_float.min(), throttle_float.max()],
                [throttle_float.min(), throttle_float.max()], 'r--', label='Perfect match')
axes[0, 1].set_xlabel('Float Model')
axes[0, 1].set_ylabel('Quantized Model')
axes[0, 1].set_title(f'Throttle: Float vs Int8 (r={throttle_corr:.4f})')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Time series comparison (steering)
n_start, n_end = 1, 300
t = range(n_start, n_end)
axes[1, 0].plot(t, y_val_steering[n_start:n_end], label='Ground Truth', linewidth=2, alpha=0.7)
axes[1, 0].plot(t, steering_float[n_start:n_end], label='Float Model', linewidth=1.5)
axes[1, 0].plot(t, steering_int8[n_start:n_end], label='Quantized Model', linewidth=1, linestyle='--')
axes[1, 0].set_ylabel('Steering')
axes[1, 0].set_title('Steering Time Series')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Time series comparison (throttle)
axes[1, 1].plot(t, y_val_throttle[n_start:n_end], label='Ground Truth', linewidth=2, alpha=0.7)
axes[1, 1].plot(t, throttle_float[n_start:n_end], label='Float Model', linewidth=1.5)
axes[1, 1].plot(t, throttle_int8[n_start:n_end], label='Quantized Model', linewidth=1, linestyle='--')
axes[1, 1].set_ylabel('Throttle')
axes[1, 1].set_title('Throttle Time Series')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()

# Error distribution
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

steering_error = steering_float - steering_int8
throttle_error = throttle_float - throttle_int8

axes[0].hist(steering_error, bins=50, edgecolor='black')
axes[0].set_xlabel('Error (Float - Int8)')
axes[0].set_ylabel('Count')
axes[0].set_title(f'Steering Quantization Error\nMean: {steering_error.mean():.6f}, Std: {steering_error.std():.6f}')
axes[0].grid(True, alpha=0.3)

axes[1].hist(throttle_error, bins=50, edgecolor='black')
axes[1].set_xlabel('Error (Float - Int8)')
axes[1].set_ylabel('Count')
axes[1].set_title(f'Throttle Quantization Error\nMean: {throttle_error.mean():.6f}, Std: {throttle_error.std():.6f}')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Running inference on validation set...
#
# Processing 757 validation samples...
#
# ============================================================
# COMPARISON: Float Model vs Quantized (int8) Model
# ============================================================
#
# STEERING:
#   MAE (quantization error): 0.004991
#   RMSE: 0.006714
#   Correlation: 0.998773
#   Float range: [-0.780, 0.708]
#   Int8 range:  [-0.781, 0.719]
#
# THROTTLE:
#   MAE (quantization error): 0.003944
#   RMSE: 0.005054
#   Correlation: 0.999589
#   Float range: [0.000, 1.000]
#   Int8 range:  [0.000, 0.996]
#
# ============================================================
# ACCURACY vs Ground Truth (y_val)
# ============================================================
#
# FLOAT MODEL:
#   Steering MAE: 0.104996
#   Throttle MAE: 0.108738
#
# QUANTIZED MODEL:
#   Steering MAE: 0.105352
#   Throttle MAE: 0.108589

# %%
# %%bash
# TFLITE_FILE="model_int8.tflite"
# BASENAME="model"
# SYMBOL="g_model"
# HEADER_GUARD="MODEL_H_"
#
# set -e
#
# # model.cc
# cat > ${BASENAME}.cc <<EOF
# #include "${BASENAME}.h"
#
# alignas(16) const unsigned char ${SYMBOL}[] = {
# EOF
#
# xxd -i ${TFLITE_FILE} \
#   | sed -n '/{/,/}/p' \
#   | sed '1d;$d' \
#   | sed 's/^/  /' \
#   >> ${BASENAME}.cc
#
# cat >> ${BASENAME}.cc <<EOF
# };
#
# const int ${SYMBOL}_len = sizeof(${SYMBOL});
# EOF
#
# # model.h
# cat > ${BASENAME}.h <<EOF
# #ifndef ${HEADER_GUARD}
# #define ${HEADER_GUARD}
#
# extern const unsigned char ${SYMBOL}[];
# extern const int ${SYMBOL}_len;
#
# #endif  // ${HEADER_GUARD}
# EOF
